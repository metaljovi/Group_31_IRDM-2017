# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from sklearn.linear_model import LinearRegression
from nltk.stem.snowball import SnowballStemmer

# %%
stemmer = SnowballStemmer('english')

# %%
df_train = pd.read_csv('train.csv', encoding="latin-1")
df_test = pd.read_csv('test.csv', encoding="latin-1")
df_attr = pd.read_csv('attributes.csv')
df_pro_desc = pd.read_csv('product_descriptions.csv')
df_brand = df_attr[df_attr.name == "MFG Brand Name"][["product_uid", "value"]].rename(columns={"value": "brand"})

num_train = df_train.shape[0]

# %%
def str_stemmer(s):
    if isinstance(s, str):
        return " ".join([stemmer.stem(word) for word in s.lower().split()])
    else:
        return "null"

def str_common_word(str1, str2):
    return sum(int(str2.find(word)>=0) for word in str1.split())

def str_whole_word(str1, str2, i_):
    cnt = 0
    while i_ < len(str2):
        i_ = str2.find(str1, i_)
        if i_ == -1:
            return cnt
        else:
            cnt += 1
            i_ += len(str1)
    return cnt

# %%
df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)
df_all = pd.merge(df_all, df_pro_desc, how='left', on='product_uid')
df_all = pd.merge(df_all, df_brand, how='left', on='product_uid')

# %%
#below you see that relevance field is NaN for what df_test
df_all[200000:]
# Out:
#             id                                      product_title  \
# 200000  188423  Hampton Bay 36x34.5x24 in. Cambria Sink Base C...
# 200001  188424  Hampton Bay 36x34.5x24 in. Cambria Sink Base C...
# 200002  188425  Glacier Bay 24 in. x 1-1/2 in. Concealed Peene...
# 200003  188426  Arizona&#39;s Best 5 lb. Tree and Shrub Food D...
# 200004  188430  Veradek 22 in. x 17.5 in. Stone Grey Venetian ...
# 200005  188432  Arlington Industries 1 in. 90-Degree Non-Metal...
# 200006  188433  Arlington Industries 1 in. 90-Degree Non-Metal...
# 200007  188435  Westinghouse 1-Light Black Exterior Wall Lante...
# 200008  188438  Filament Design Johnson 4-Light Rustic Iron In...
# 200009  188439      Master Flow 13 in. x 18 in. Fixed Chimney Cap
# 200010  188440              Bosch 7-1/4 in. 40T Non-Ferrous Blade
# 200011  188441  Masonite 24 in. x 80 in. Roman Smooth 2-Panel ...
# 200012  188442  Mohawk Raymore Oak Saddle 3/4 in. Thick x 2-1/...
# 200013  188443  BEHR Premium Plus Ultra #220F-5 Light Mocha Paint
# 200014  188444  UDECX 3-1/6 ft. x 2 in. x 2 in. Black Aluminum...
# 200015  188446                  Husky 6.5 in. Deep-Cut Coping Saw
# 200016  188447                  Husky 6.5 in. Deep-Cut Coping Saw
# 200017  188448  Ekena Millwork 2-1/2 in. x 2-3/4 in. x 94-5/8 ...
# 200018  188449                        3 in. Flexible PVC Coupling
# 200019  188450  EnviroLite 6 in. Decorative Brushed Nickel Tri...
# 200020  188451  EnviroLite 6 in. Decorative Brushed Nickel Tri...
# 200021  188452  EnviroLite 6 in. Decorative Brushed Nickel Tri...
# 200022  188453  Rust-Oleum FlexiDip 11 oz. White Spray Paint (...
# 200023  188455  Cake Boss Decorating Tools, Turntable and Cake...
# 200024  188457  Whirlpool Gold 30 in. Electric Convection Wall...
# 200025  188458  Whirlpool Gold 30 in. Electric Convection Wall...
# 200026  188460  Whirlpool Gold 30 in. Electric Convection Wall...
# 200027  188461  Whirlpool Gold 30 in. Electric Convection Wall...
# 200028  188462  General Tools Rugged CAT III 600-Volt Multi-Me...
# 200029  188463  RiverRidge Home Ellsworth 18 in. W Single Door...
# ...        ...                                                ...
# 240730  240731                      6-Panel Composite Bifold Door
# 240731  240732     Eaton CSR 200-Amp Double Pole Main Breaker Kit
# 240732  240733  Crown Bolt 3/16 in. Zinc Plated Steel Axle Hat...
# 240733  240734              Dickies 2-Pocket Utility Knife Sheath
# 240734  240735  Patio Living Concepts San Juan 60 in. Outdoor ...
# 240735  240736             Speakman Emergency Eyewash Safety Sign
# 240736  240737      Plantronics Cable for M12 and CS50/CS55 Phone
# 240737  240738  Glomar Vanguard 9-Light Textured Black Chandel...
# 240738  240739        Kwikset Milan Satin Nickel Half-Dummy Lever
# 240739  240740  Advanced Drainage Systems 1/2 in. x 100 ft. IP...
# 240740  240741  Magnavox 50 in. Class LED 1080p 120 BMR Slim HDTV
# 240741  240742  Ekena Millwork 7 in. x 3/4 in. x 11 in. Hillsb...
# 240742  240743  Minwax 1 gal. Semi-Gloss Polycrylic Protective...
# 240743  240744  Southern Living Plant Collection 3 Gal. Pink S...
# 240744  240745  GE 5.0 cu. ft. Gas Range with Self-Cleaning Ov...
# 240745  240746  Southwire 150 ft. 12-3 CU W/G Submersible Pump...
# 240746  240747  Generac Protector Series 15,000-Watt 120/240-V...
# 240747  240748  KOHLER Clearflo Brass Toe Tap Bath Drain in Vi...
# 240748  240749  Casablanca 4-Light Maiden Bronze Ceiling Fan F...
# 240749  240750  Glidden Premium 5-gal. #HDGR19 Fresh Peonies S...
# 240750  240751  Everbilt 1/8 in. x 50 ft. Reflective Black Par...
# 240751  240752  Crown Bolt 5/16 in. (1/4 in.-20) x 1-1/2 in. A...
# 240752  240753  Universal Tubs 4.5 ft. Right Drain Wheel Chair...
# 240753  240754  Everbilt #12 x 1-1/2 in. Phillips Brass Flat-H...
# 240754  240755  Coastal Shower Doors Legend Series 24 in. x 64...
# 240755  240756  stufurhome Norma 24 in. W x 16 in. D x 34 in. ...
# 240756  240757  Home Decorators Collection 49 in. D Alessandro...
# 240757  240758  Simpson Strong-Tie HB 3-1/2 x 14 in. Top Flang...
# 240758  240759  1/4 in. -20 tpi x 1-1/2 in. Stainless Steel Bu...
# 240759  240760                      Bosch 4 in. Bi-Metal Hole Saw
#
#         product_uid  relevance                       search_term  \
# 200000       180429        NaN                             36x94
# 200001       180429        NaN        cambria java refridgerator
# 200002       180430        NaN                   glacier bar sin
# 200003       180431        NaN                eb stone tree food
# 200004       180434        NaN           small flower pot stones
# 200005       180436        NaN          liquid itght non metalic
# 200006       180436        NaN      liquid tight romex connector
# 200007       180438        NaN         black exterior chandelier
# 200008       180441        NaN            iron bath vanity light
# 200009       180442        NaN          flange mount chimney cap
# 200010       180443        NaN             non ferroue saw blade
# 200011       180444        NaN             24 inch preying doors
# 200012       180445        NaN                       raymore oak
# 200013       180446        NaN        mocha brown paint interior
# 200014       180447        NaN                 deck 2 black post
# 200015       180449        NaN                         hand saws
# 200016       180449        NaN                  husky pro 24901p
# 200017       180450        NaN         crown  molding 2 1/2 inch
# 200018       180451        NaN                  pvc coupling 3 6
# 200019       180452        NaN           oppeuss light trim ring
# 200020       180452        NaN   recessed light with ventilation
# 200021       180452        NaN         rrecessed light trim ring
# 200022       180453        NaN              plasti dip -flexidip
# 200023       180454        NaN           magnet base tool loight
# 200024       180456        NaN              30 in Microwave oven
# 200025       180456        NaN         microwave convection oven
# 200026       180456        NaN         microwave oven thermostat
# 200027       180456        NaN               wall oven microwave
# 200028       180457        NaN                general multi tool
# 200029       180458        NaN  door floor plate  slideing doors
# ...             ...        ...                               ...
# 240730       224399        NaN          bifold oak 6 panel doors
# 240731       224400        NaN       200 amp breaker double pole
# 240732       224401        NaN                 axle locking nuts
# 240733       224402        NaN                            sheath
# 240734       224403        NaN              outdoor patio shades
# 240735       224404        NaN                      safety signs
# 240736       224405        NaN                       phone cable
# 240737       224406        NaN                          vanguard
# 240738       224407        NaN                      dummy handle
# 240739       224408        NaN         Advanced drainage systems
# 240740       224409        NaN                           led tvs
# 240741       224410        NaN                         l molding
# 240742       224411        NaN                 minwax polycrylic
# 240743       224412        NaN                         camellias
# 240744       224413        NaN                  black gas ranges
# 240745       224414        NaN                  submersible wire
# 240746       224415        NaN     32kw generac protector series
# 240747       224416        NaN                     bathroom taps
# 240748       224417        NaN        ceiling fan light fixtures
# 240749       224418        NaN                           Peonies
# 240750       224419        NaN                          paracord
# 240751       224420        NaN              2 inch  1/4-20 bolts
# 240752       224421        NaN                       bath chairs
# 240753       224422        NaN                         1/2 brass
# 240754       224423        NaN                pivot shower doors
# 240755       224424        NaN          24 whtie storage cabinet
# 240756       224425        NaN                 adirondeck cusion
# 240757       224426        NaN                                hb
# 240758       224427        NaN                       hex sockets
# 240759       224428        NaN                   4 inch hole saw
#
#                                       product_description  \
# 200000  The furniture-quality finish on the Hampton Ba...
# 200001  The furniture-quality finish on the Hampton Ba...
# 200002  The Glacier Bay 24 in. x 1-1/2 in. Concealed P...
# 200003  Tree and Shrub Food is packaged in a convenien...
# 200004  Featuring a traditional Mediterranean Urn desi...
# 200005  The ARLINGTON INDUSTRIES INC 1 in. 90-Degree N...
# 200006  The ARLINGTON INDUSTRIES INC 1 in. 90-Degree N...
# 200007  This Westinghouse Exterior Wall Lantern featur...
# 200008  The Johnson Collection is well known for quali...
# 200009  Master Flow Chimney caps provide protection ag...
# 200010  Bosch circular saw blades apply the best techn...
# 200011  Enjoy refined style and easy elegance with the...
# 200012  The natural stylings of this durable, traditio...
# 200013  BEHR Premium Plus Ultra Semi-Gloss Enamel Exte...
# 200014  The Udecx patio decking system utilizes 2 in. ...
# 200015  The 6 in. Deep-Cut Coping Saw is designed for ...
# 200016  The 6 in. Deep-Cut Coping Saw is designed for ...
# 200017  Beautiful crown moulding is a great way to sep...
# 200018  The Fernco 3 in. Flexible PVC Coupling is idea...
# 200019  EnviroLite 6 in. interchangeable trim rings al...
# 200020  EnviroLite 6 in. interchangeable trim rings al...
# 200021  EnviroLite 6 in. interchangeable trim rings al...
# 200022  Rust-Oleum FlexiDip is a multi-use rubberized ...
# 200023  Put an easy spin on decorating and showcasing ...
# 200024  Quickly moving dinner from the oven to the tab...
# 200025  Quickly moving dinner from the oven to the tab...
# 200026  Quickly moving dinner from the oven to the tab...
# 200027  Quickly moving dinner from the oven to the tab...
# 200028  Since 1910, General Tools has grown to become ...
# 200029  River Ridge Home Single Door Floor Cabinet in ...
# ...                                                   ...
# 240730  Give your home a custom look with Plantation s...
# 240731  The Eaton CSR 200-Amp Double-Pole Main Breaker...
# 240732  These push nuts have no screw thread but have ...
# 240733  The Dickies Utility Knife Sheath is constructe...
# 240734  Carefree resin durability, while adding elegan...
# 240735  The Speakman branded emergency eyewash safety ...
# 240736  The PL-65111-01 is a Plantronics phone accesso...
# 240737  The 1940's are back with a hint of today. Avai...
# 240738  Step up to designer styles and superior securi...
# 240739  1/2 in. x 100 ft. IPS 125 psi NSF Poly Pipe is...
# 240740  Enjoy optimal viewing areas with the Magnavox ...
# 240741  Beautiful crown moulding is a great way to sep...
# 240742  Minwax Polycrylic Protective Finish is a prote...
# 240743  The Pink Stella Camellia from the Southern Liv...
# 240744  Your GE 30 in. 5.0 cu. ft. Gas Range with Self...
# 240745  Southwires Submersible Pump cable is used subm...
# 240746  Generacs new Protector Series diesel generator...
# 240747  The Clearflo Brass Toe-tap bath drain works pe...
# 240748  The Light Kit by Casablanca is a great design ...
# 240749  The Glidden Premium 5-gal. Satin Latex Exterio...
# 240750  Paracord is ideal for camping, hiking and othe...
# 240751  Crown Bolt's shoulder bolts are also known as ...
# 240752  Wheel Chair Accessible's provide a safe and in...
# 240753  These wood screws are thread forming screws wi...
# 240754  The Legend Series framed swing stand-alone con...
# 240755  Create a neat yet stylish storage space for or...
# 240756  Our Bullnose Adirondack Chair Cushions fit Adi...
# 240757  Joist hangers are designed to provide support ...
# 240758  These socket cap screws are ideal for applicat...
# 240759  The Bosch quick change bi-metal hole saws feat...
#
#                                    brand
# 200000                       Hampton Bay
# 200001                       Hampton Bay
# 200002                       Glacier Bay
# 200003                    Arizona's Best
# 200004                           Veradek
# 200005              Arlington Industries
# 200006              Arlington Industries
# 200007                      Westinghouse
# 200008                   Filament Design
# 200009                       Master Flow
# 200010                             Bosch
# 200011                          Masonite
# 200012                            Mohawk
# 200013           BEHR Premium Plus Ultra
# 200014                             UDECX
# 200015                             Husky
# 200016                             Husky
# 200017                    Ekena Millwork
# 200018                            Fernco
# 200019                        EnviroLite
# 200020                        EnviroLite
# 200021                        EnviroLite
# 200022               Rust-Oleum FlexiDip
# 200023                         Cake Boss
# 200024                         Whirlpool
# 200025                         Whirlpool
# 200026                         Whirlpool
# 200027                         Whirlpool
# 200028                     General Tools
# 200029                   RiverRidge Home
# ...                                  ...
# 240730         Home Fashion Technologies
# 240731                             Eaton
# 240732                        Crown Bolt
# 240733                           Dickies
# 240734             Patio Living Concepts
# 240735                          Speakman
# 240736                       Plantronics
# 240737                            Glomar
# 240738                           Kwikset
# 240739         Advanced Drainage Systems
# 240740                          Magnavox
# 240741                    Ekena Millwork
# 240742                            Minwax
# 240743  Southern Living Plant Collection
# 240744                                GE
# 240745                         Southwire
# 240746                           Generac
# 240747                            KOHLER
# 240748                        Casablanca
# 240749                               NaN
# 240750                          Everbilt
# 240751                        Crown Bolt
# 240752                    Universal Tubs
# 240753                          Everbilt
# 240754              Coastal Shower Doors
# 240755                        stufurhome
# 240756        Home Decorators Collection
# 240757                               NaN
# 240758                               NaN
# 240759                             Bosch
#
# [40760 rows x 7 columns]

# %%
list(df_all)
# Out:
# ['id',
#  'product_title',
#  'product_uid',
#  'relevance',
#  'search_term',
#  'product_description',
#  'brand']

# %% [markdown]
# ## Features

# %%
df_all['search_term'] = df_all['search_term'].map(lambda x:str_stemmer(x))

# %%
df_all['product_title'] = df_all['product_title'].map(lambda x:str_stemmer(x))

# %%
df_all['product_description'] = df_all['product_description'].map(lambda x:str_stemmer(x))

# %%
df_all['brand'] = df_all['brand'].map(lambda x:str_stemmer(x))

# %%
df_all['len_of_query'] = df_all['search_term'].map(lambda x:len(x.split())).astype(np.int64)

# %%
df_all['len_of_title'] = df_all['product_title'].map(lambda x:len(x.split())).astype(np.int64)

# %%
df_all['len_of_description'] = df_all['product_description'].map(lambda x:len(x.split())).astype(np.int64)

# %%
df_all['len_of_brand'] = df_all['brand'].map(lambda x:len(x.split())).astype(np.int64)

# %%
df_all['product_info'] = df_all['search_term']+"\t"+df_all['product_title']+"\t"+df_all['product_description']

# %%
df_all['word_in_title'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[1]))

# %%
df_all['word_in_description'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[2]))

# %%
df_all['query_in_title'] = df_all['product_info'].map(lambda x:str_whole_word(x.split('\t')[0],x.split('\t')[1],0))

# %%
df_all['query_in_description'] = df_all['product_info'].map(lambda x:str_whole_word(x.split('\t')[0],x.split('\t')[2],0))

# %%
df_all['query_last_word_in_title'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0].split(" ")[-1],x.split('\t')[1]))

# %%
df_all['query_last_word_in_description'] = df_all['product_info'].map(lambda x:str_common_word(x.split('\t')[0].split(" ")[-1],x.split('\t')[2]))

# %%
df_all['ratio_title'] = df_all['word_in_title'] / df_all['len_of_query']

# %%
df_all['ratio_description'] = df_all['word_in_description']/df_all['len_of_query']

# %%
df_all['attr'] = df_all['search_term']+"\t"+df_all['brand']

# %%
df_all['word_in_brand'] = df_all['attr'].map(lambda x:str_common_word(x.split('\t')[0],x.split('\t')[1]))

# %%
df_all['ratio_brand'] = df_all['word_in_brand']/df_all['len_of_brand']

# %%
df_brand = pd.unique(df_all.brand.ravel())

# %%
df_all[200000:]
# Out:
#             id                                      product_title  \
# 200000  188423  hampton bay 36x34.5x24 in. cambria sink base c...
# 200001  188424  hampton bay 36x34.5x24 in. cambria sink base c...
# 200002  188425  glacier bay 24 in. x 1-1/2 in. conceal peen gr...
# 200003  188426  arizona&#39; best 5 lb. tree and shrub food dr...
# 200004  188430  veradek 22 in. x 17.5 in. stone grey venetian ...
# 200005  188432  arlington industri 1 in. 90-degre non-metal li...
# 200006  188433  arlington industri 1 in. 90-degre non-metal li...
# 200007  188435  westinghous 1-light black exterior wall lanter...
# 200008  188438  filament design johnson 4-light rustic iron in...
# 200009  188439        master flow 13 in. x 18 in. fix chimney cap
# 200010  188440                 bosch 7-1/4 in. 40t non-ferr blade
# 200011  188441  masonit 24 in. x 80 in. roman smooth 2-panel r...
# 200012  188442  mohawk raymor oak saddl 3/4 in. thick x 2-1/4 ...
# 200013  188443  behr premium plus ultra #220f-5 light mocha paint
# 200014  188444  udecx 3-1/6 ft. x 2 in. x 2 in. black aluminum...
# 200015  188446                    huski 6.5 in. deep-cut cope saw
# 200016  188447                    huski 6.5 in. deep-cut cope saw
# 200017  188448  ekena millwork 2-1/2 in. x 2-3/4 in. x 94-5/8 ...
# 200018  188449                            3 in. flexibl pvc coupl
# 200019  188450  envirolit 6 in. decor brush nickel trim ring f...
# 200020  188451  envirolit 6 in. decor brush nickel trim ring f...
# 200021  188452  envirolit 6 in. decor brush nickel trim ring f...
# 200022  188453  rust-oleum flexidip 11 oz. white spray paint (...
# 200023  188455  cake boss decor tools, turntabl and cake stand...
# 200024  188457  whirlpool gold 30 in. electr convect wall oven...
# 200025  188458  whirlpool gold 30 in. electr convect wall oven...
# 200026  188460  whirlpool gold 30 in. electr convect wall oven...
# 200027  188461  whirlpool gold 30 in. electr convect wall oven...
# 200028  188462  general tool rug cat iii 600-volt multi-met wi...
# 200029  188463  riverridg home ellsworth 18 in. w singl door f...
# ...        ...                                                ...
# 240730  240731                       6-panel composit bifold door
# 240731  240732      eaton csr 200-amp doubl pole main breaker kit
# 240732  240733  crown bolt 3/16 in. zinc plate steel axl hat n...
# 240733  240734                   dicki 2-pocket util knife sheath
# 240734  240735  patio live concept san juan 60 in. outdoor bis...
# 240735  240736                 speakman emerg eyewash safeti sign
# 240736  240737          plantron cabl for m12 and cs50/cs55 phone
# 240737  240738  glomar vanguard 9-light textur black chandeli ...
# 240738  240739        kwikset milan satin nickel half-dummi lever
# 240739  240740  advanc drainag system 1/2 in. x 100 ft. ip 125...
# 240740  240741  magnavox 50 in. class led 1080p 120 bmr slim hdtv
# 240741  240742  ekena millwork 7 in. x 3/4 in. x 11 in. hillsb...
# 240742  240743   minwax 1 gal. semi-gloss polycryl protect finish
# 240743  240744  southern live plant collect 3 gal. pink stella...
# 240744  240745  ge 5.0 cu. ft. gas rang with self-clean oven i...
# 240745  240746     southwir 150 ft. 12-3 cu w/g submers pump cabl
# 240746  240747  generac protector seri 15,000-watt 120/240-vol...
# 240747  240748  kohler clearflo brass toe tap bath drain in vi...
# 240748  240749  casablanca 4-light maiden bronz ceil fan fixtu...
# 240749  240750  glidden premium 5-gal. #hdgr19 fresh peoni sat...
# 240750  240751   everbilt 1/8 in. x 50 ft. reflect black paracord
# 240751  240752  crown bolt 5/16 in. (1/4 in.-20) x 1-1/2 in. a...
# 240752  240753  univers tub 4.5 ft. right drain wheel chair ac...
# 240753  240754  everbilt #12 x 1-1/2 in. phillip brass flat-he...
# 240754  240755  coastal shower door legend seri 24 in. x 64 in...
# 240755  240756  stufurhom norma 24 in. w x 16 in. d x 34 in. h...
# 240756  240757  home decor collect 49 in. d alessandro spicebe...
# 240757  240758  simpson strong-ti hb 3-1/2 x 14 in. top flang ...
# 240758  240759  1/4 in. -20 tpi x 1-1/2 in. stainless steel bu...
# 240759  240760                        bosch 4 in. bi-met hole saw
#
#         product_uid  relevance                   search_term  \
# 200000       180429        NaN                         36x94
# 200001       180429        NaN        cambria java refridger
# 200002       180430        NaN               glacier bar sin
# 200003       180431        NaN            eb stone tree food
# 200004       180434        NaN        small flower pot stone
# 200005       180436        NaN        liquid itght non metal
# 200006       180436        NaN  liquid tight romex connector
# 200007       180438        NaN       black exterior chandeli
# 200008       180441        NaN        iron bath vaniti light
# 200009       180442        NaN       flang mount chimney cap
# 200010       180443        NaN          non ferrou saw blade
# 200011       180444        NaN             24 inch prey door
# 200012       180445        NaN                    raymor oak
# 200013       180446        NaN    mocha brown paint interior
# 200014       180447        NaN             deck 2 black post
# 200015       180449        NaN                      hand saw
# 200016       180449        NaN              huski pro 24901p
# 200017       180450        NaN         crown mold 2 1/2 inch
# 200018       180451        NaN                 pvc coupl 3 6
# 200019       180452        NaN       oppeuss light trim ring
# 200020       180452        NaN      recess light with ventil
# 200021       180452        NaN       rrecess light trim ring
# 200022       180453        NaN          plasti dip -flexidip
# 200023       180454        NaN       magnet base tool loight
# 200024       180456        NaN           30 in microwav oven
# 200025       180456        NaN         microwav convect oven
# 200026       180456        NaN      microwav oven thermostat
# 200027       180456        NaN            wall oven microwav
# 200028       180457        NaN            general multi tool
# 200029       180458        NaN   door floor plate slide door
# ...             ...        ...                           ...
# 240730       224399        NaN       bifold oak 6 panel door
# 240731       224400        NaN    200 amp breaker doubl pole
# 240732       224401        NaN                  axl lock nut
# 240733       224402        NaN                        sheath
# 240734       224403        NaN           outdoor patio shade
# 240735       224404        NaN                   safeti sign
# 240736       224405        NaN                    phone cabl
# 240737       224406        NaN                      vanguard
# 240738       224407        NaN                   dummi handl
# 240739       224408        NaN         advanc drainag system
# 240740       224409        NaN                       led tvs
# 240741       224410        NaN                        l mold
# 240742       224411        NaN               minwax polycryl
# 240743       224412        NaN                      camellia
# 240744       224413        NaN                black gas rang
# 240745       224414        NaN                  submers wire
# 240746       224415        NaN   32kw generac protector seri
# 240747       224416        NaN                  bathroom tap
# 240748       224417        NaN         ceil fan light fixtur
# 240749       224418        NaN                         peoni
# 240750       224419        NaN                      paracord
# 240751       224420        NaN            2 inch 1/4-20 bolt
# 240752       224421        NaN                    bath chair
# 240753       224422        NaN                     1/2 brass
# 240754       224423        NaN             pivot shower door
# 240755       224424        NaN       24 whtie storag cabinet
# 240756       224425        NaN             adirondeck cusion
# 240757       224426        NaN                            hb
# 240758       224427        NaN                    hex socket
# 240759       224428        NaN               4 inch hole saw
#
#                                       product_description  \
# 200000  the furniture-qu finish on the hampton bay bas...
# 200001  the furniture-qu finish on the hampton bay bas...
# 200002  the glacier bay 24 in. x 1-1/2 in. conceal pee...
# 200003  tree and shrub food is packag in a conveni 5 l...
# 200004  featur a tradit mediterranean urn design, the ...
# 200005  the arlington industri inc 1 in. 90-degre non-...
# 200006  the arlington industri inc 1 in. 90-degre non-...
# 200007  this westinghous exterior wall lantern featur ...
# 200008  the johnson collect is well known for quality,...
# 200009  master flow chimney cap provid protect against...
# 200010  bosch circular saw blade appli the best techno...
# 200011  enjoy refin style and easi eleg with the mason...
# 200012  the natur style of this durable, tradit oak ha...
# 200013  behr premium plus ultra semi-gloss enamel exte...
# 200014  the udecx patio deck system util 2 in. squar r...
# 200015  the 6 in. deep-cut cope saw is design for scro...
# 200016  the 6 in. deep-cut cope saw is design for scro...
# 200017  beauti crown mould is a great way to separ and...
# 200018  the fernco 3 in. flexibl pvc coupl is ideal fo...
# 200019  envirolit 6 in. interchang trim ring allow you...
# 200020  envirolit 6 in. interchang trim ring allow you...
# 200021  envirolit 6 in. interchang trim ring allow you...
# 200022  rust-oleum flexidip is a multi-us rubber coat ...
# 200023  put an easi spin on decor and showcas those ey...
# 200024  quick move dinner from the oven to the tabl ha...
# 200025  quick move dinner from the oven to the tabl ha...
# 200026  quick move dinner from the oven to the tabl ha...
# 200027  quick move dinner from the oven to the tabl ha...
# 200028  sinc 1910, general tool has grown to becom the...
# 200029  river ridg home singl door floor cabinet in an...
# ...                                                   ...
# 240730  give your home a custom look with plantat styl...
# 240731  the eaton csr 200-amp double-pol main breaker ...
# 240732  these push nut have no screw thread but have a...
# 240733  the dicki util knife sheath is construct of ru...
# 240734  carefre resin durability, while ad eleg to ani...
# 240735  the speakman brand emerg eyewash safeti sign. ...
# 240736  the pl-65111-01 is a plantron phone accessori ...
# 240737  the 1940 are back with a hint of today. avail ...
# 240738  step up to design style and superior secur wit...
# 240739  1/2 in. x 100 ft. ip 125 psi nsf poli pipe is ...
# 240740  enjoy optim view area with the magnavox 50 in....
# 240741  beauti crown mould is a great way to separ and...
# 240742  minwax polycryl protect finish is a protect to...
# 240743  the pink stella camellia from the southern liv...
# 240744  your ge 30 in. 5.0 cu. ft. gas rang with self-...
# 240745  southwir submers pump cabl is use submers pump...
# 240746  generac new protector seri diesel generat rais...
# 240747  the clearflo brass toe-tap bath drain work per...
# 240748  the light kit by casablanca is a great design ...
# 240749  the glidden premium 5-gal. satin latex exterio...
# 240750  paracord is ideal for camping, hike and other ...
# 240751  crown bolt shoulder bolt are also known as str...
# 240752  wheel chair access provid a safe and independ ...
# 240753  these wood screw are thread form screw with la...
# 240754  the legend seri frame swing stand-alon continu...
# 240755  creat a neat yet stylish storag space for orga...
# 240756  our bullnos adirondack chair cushion fit adiro...
# 240757  joist hanger are design to provid support unde...
# 240758  these socket cap screw are ideal for applic th...
# 240759  the bosch quick chang bi-met hole saw featur p...
#
#                               brand  len_of_query  len_of_title  \
# 200000                  hampton bay             1            10
# 200001                  hampton bay             3            10
# 200002                  glacier bay             3            15
# 200003                 arizona best             4            10
# 200004                      veradek             4            12
# 200005           arlington industri             4             9
# 200006           arlington industri             4             9
# 200007                  westinghous             3            15
# 200008              filament design             4            10
# 200009                  master flow             4            10
# 200010                        bosch             4             6
# 200011                      masonit             4            20
# 200012                       mohawk             2            22
# 200013      behr premium plus ultra             4             8
# 200014                        udecx             4            14
# 200015                        huski             2             6
# 200016                        huski             3             6
# 200017               ekena millwork             5            14
# 200018                       fernco             4             5
# 200019                    envirolit             4            16
# 200020                    envirolit             4            16
# 200021                    envirolit             4            16
# 200022          rust-oleum flexidip             3             8
# 200023                    cake boss             4            13
# 200024                    whirlpool             4            14
# 200025                    whirlpool             3            14
# 200026                    whirlpool             3            14
# 200027                    whirlpool             3            14
# 200028                 general tool             3            16
# 200029               riverridg home             5            12
# ...                             ...           ...           ...
# 240730       home fashion technolog             5             4
# 240731                        eaton             5             8
# 240732                   crown bolt             3            11
# 240733                        dicki             1             5
# 240734           patio live concept             3            15
# 240735                     speakman             2             5
# 240736                     plantron             2             7
# 240737                       glomar             1            10
# 240738                      kwikset             2             6
# 240739        advanc drainag system             3            14
# 240740                     magnavox             2            10
# 240741               ekena millwork             2            15
# 240742                       minwax             2             7
# 240743  southern live plant collect             1             9
# 240744                           ge             3            11
# 240745                     southwir             2             9
# 240746                      generac             4            12
# 240747                       kohler             2            11
# 240748                   casablanca             4            11
# 240749                         null             1            10
# 240750                     everbilt             1             9
# 240751                   crown bolt             4            12
# 240752                  univers tub             2            16
# 240753                     everbilt             2            13
# 240754          coastal shower door             3            19
# 240755                    stufurhom             4            19
# 240756           home decor collect             2            15
# 240757                         null             1            11
# 240758                         null             2            18
# 240759                        bosch             4             6
#
#         len_of_description     ...       word_in_description query_in_title  \
# 200000                 100     ...                         0              0
# 200001                 100     ...                         0              0
# 200002                 109     ...                         2              0
# 200003                  97     ...                         2              0
# 200004                 218     ...                         1              0
# 200005                  48     ...                         3              0
# 200006                  48     ...                         3              0
# 200007                 210     ...                         2              0
# 200008                  82     ...                         3              0
# 200009                  97     ...                         2              0
# 200010                 115     ...                         2              0
# 200011                 116     ...                         1              0
# 200012                 183     ...                         1              1
# 200013                 180     ...                         1              0
# 200014                  95     ...                         4              0
# 200015                  74     ...                         1              0
# 200016                  74     ...                         1              0
# 200017                 161     ...                         3              0
# 200018                  64     ...                         3              0
# 200019                  89     ...                         3              0
# 200020                  89     ...                         2              0
# 200021                  89     ...                         3              0
# 200022                 230     ...                         2              0
# 200023                 248     ...                         2              0
# 200024                 371     ...                         3              0
# 200025                 371     ...                         3              0
# 200026                 371     ...                         2              0
# 200027                 371     ...                         3              0
# 200028                 268     ...                         3              0
# 200029                 131     ...                         3              0
# ...                    ...     ...                       ...            ...
# 240730                  78     ...                         3              0
# 240731                 158     ...                         5              0
# 240732                  79     ...                         1              0
# 240733                  72     ...                         1              1
# 240734                  47     ...                         2              0
# 240735                  52     ...                         2              1
# 240736                  39     ...                         2              0
# 240737                  73     ...                         1              1
# 240738                 130     ...                         0              0
# 240739                  60     ...                         0              1
# 240740                 127     ...                         1              0
# 240741                 155     ...                         1              0
# 240742                 133     ...                         2              0
# 240743                  92     ...                         1              1
# 240744                 301     ...                         3              0
# 240745                  57     ...                         1              0
# 240746                 268     ...                         3              0
# 240747                 130     ...                         2              0
# 240748                  56     ...                         3              0
# 240749                 170     ...                         0              1
# 240750                 213     ...                         1              1
# 240751                  99     ...                         1              0
# 240752                 222     ...                         2              0
# 240753                  95     ...                         2              0
# 240754                 125     ...                         2              0
# 240755                 117     ...                         3              0
# 240756                 119     ...                         0              0
# 240757                  81     ...                         1              1
# 240758                  84     ...                         2              1
# 240759                  74     ...                         2              0
#
#         query_in_description  query_last_word_in_title  \
# 200000                     0                         0
# 200001                     0                         0
# 200002                     0                         0
# 200003                     0                         1
# 200004                     0                         1
# 200005                     0                         1
# 200006                     0                         1
# 200007                     0                         0
# 200008                     0                         1
# 200009                     0                         1
# 200010                     0                         1
# 200011                     0                         1
# 200012                     0                         1
# 200013                     0                         0
# 200014                     0                         1
# 200015                     0                         1
# 200016                     0                         0
# 200017                     0                         0
# 200018                     0                         0
# 200019                     0                         1
# 200020                     0                         0
# 200021                     0                         1
# 200022                     0                         0
# 200023                     0                         0
# 200024                     0                         1
# 200025                     0                         1
# 200026                     0                         0
# 200027                     0                         1
# 200028                     0                         1
# 200029                     0                         1
# ...                      ...                       ...
# 240730                     0                         1
# 240731                     0                         1
# 240732                     0                         1
# 240733                     2                         1
# 240734                     0                         1
# 240735                     2                         1
# 240736                     0                         1
# 240737                     1                         1
# 240738                     0                         0
# 240739                     0                         1
# 240740                     0                         0
# 240741                     0                         0
# 240742                     2                         1
# 240743                     2                         1
# 240744                     0                         1
# 240745                     0                         0
# 240746                     0                         1
# 240747                     0                         1
# 240748                     0                         1
# 240749                     0                         1
# 240750                     8                         1
# 240751                     0                         1
# 240752                     0                         1
# 240753                     0                         1
# 240754                     0                         1
# 240755                     0                         1
# 240756                     0                         0
# 240757                     1                         1
# 240758                     0                         1
# 240759                     0                         1
#
#         query_last_word_in_description  ratio_title  ratio_description  \
# 200000                               0     0.000000           0.000000
# 200001                               0     0.666667           0.000000
# 200002                               0     0.666667           0.666667
# 200003                               1     0.500000           0.500000
# 200004                               1     0.250000           0.250000
# 200005                               1     0.750000           0.750000
# 200006                               1     0.750000           0.750000
# 200007                               0     0.666667           0.666667
# 200008                               1     1.000000           0.750000
# 200009                               1     0.500000           0.500000
# 200010                               1     0.500000           0.500000
# 200011                               1     0.500000           0.250000
# 200012                               1     1.000000           0.500000
# 200013                               0     0.500000           0.250000
# 200014                               1     0.750000           1.000000
# 200015                               1     0.500000           0.500000
# 200016                               0     0.333333           0.333333
# 200017                               0     0.600000           0.600000
# 200018                               0     0.750000           0.750000
# 200019                               1     0.750000           0.750000
# 200020                               0     0.750000           0.500000
# 200021                               1     0.750000           0.750000
# 200022                               0     0.333333           0.666667
# 200023                               0     0.500000           0.500000
# 200024                               1     1.000000           0.750000
# 200025                               1     1.000000           1.000000
# 200026                               0     0.666667           0.666667
# 200027                               1     1.000000           1.000000
# 200028                               1     1.000000           1.000000
# 200029                               1     0.600000           0.600000
# ...                                ...          ...                ...
# 240730                               1     0.800000           0.600000
# 240731                               1     1.000000           1.000000
# 240732                               1     0.666667           0.333333
# 240733                               1     1.000000           1.000000
# 240734                               1     1.000000           0.666667
# 240735                               1     1.000000           1.000000
# 240736                               1     1.000000           1.000000
# 240737                               1     1.000000           1.000000
# 240738                               0     0.500000           0.000000
# 240739                               0     1.000000           0.000000
# 240740                               0     0.500000           0.500000
# 240741                               0     0.500000           0.500000
# 240742                               1     1.000000           1.000000
# 240743                               1     1.000000           1.000000
# 240744                               1     1.000000           1.000000
# 240745                               0     0.500000           0.500000
# 240746                               1     0.750000           0.750000
# 240747                               1     0.500000           1.000000
# 240748                               0     1.000000           0.750000
# 240749                               0     1.000000           0.000000
# 240750                               1     1.000000           1.000000
# 240751                               1     0.500000           0.250000
# 240752                               1     1.000000           1.000000
# 240753                               1     1.000000           1.000000
# 240754                               1     0.666667           0.666667
# 240755                               1     0.750000           0.750000
# 240756                               0     0.000000           0.000000
# 240757                               1     1.000000           1.000000
# 240758                               1     1.000000           1.000000
# 240759                               1     0.750000           0.500000
#
#                                                      attr  word_in_brand  \
# 200000                                 36x94\thampton bay              0
# 200001                cambria java refridger\thampton bay              0
# 200002                       glacier bar sin\tglacier bay              1
# 200003                   eb stone tree food\tarizona best              0
# 200004                    small flower pot stone\tveradek              0
# 200005         liquid itght non metal\tarlington industri              0
# 200006   liquid tight romex connector\tarlington industri              0
# 200007               black exterior chandeli\twestinghous              0
# 200008            iron bath vaniti light\tfilament design              0
# 200009               flang mount chimney cap\tmaster flow              0
# 200010                        non ferrou saw blade\tbosch              0
# 200011                         24 inch prey door\tmasonit              0
# 200012                                 raymor oak\tmohawk              0
# 200013  mocha brown paint interior\tbehr premium plus ...              0
# 200014                           deck 2 black post\tudecx              0
# 200015                                    hand saw\thuski              0
# 200016                            huski pro 24901p\thuski              1
# 200017              crown mold 2 1/2 inch\tekena millwork              0
# 200018                              pvc coupl 3 6\tfernco              0
# 200019                 oppeuss light trim ring\tenvirolit              0
# 200020                recess light with ventil\tenvirolit              0
# 200021                 rrecess light trim ring\tenvirolit              0
# 200022          plasti dip -flexidip\trust-oleum flexidip              1
# 200023                 magnet base tool loight\tcake boss              0
# 200024                     30 in microwav oven\twhirlpool              0
# 200025                   microwav convect oven\twhirlpool              0
# 200026                microwav oven thermostat\twhirlpool              0
# 200027                      wall oven microwav\twhirlpool              0
# 200028                   general multi tool\tgeneral tool              2
# 200029        door floor plate slide door\triverridg home              0
# ...                                                   ...            ...
# 240730    bifold oak 6 panel door\thome fashion technolog              0
# 240731                  200 amp breaker doubl pole\teaton              0
# 240732                           axl lock nut\tcrown bolt              0
# 240733                                      sheath\tdicki              0
# 240734            outdoor patio shade\tpatio live concept              1
# 240735                              safeti sign\tspeakman              0
# 240736                               phone cabl\tplantron              0
# 240737                                   vanguard\tglomar              0
# 240738                               dummi handl\tkwikset              0
# 240739       advanc drainag system\tadvanc drainag system              3
# 240740                                  led tvs\tmagnavox              0
# 240741                             l mold\tekena millwork              1
# 240742                            minwax polycryl\tminwax              1
# 240743              camellia\tsouthern live plant collect              0
# 240744                                 black gas rang\tge              0
# 240745                             submers wire\tsouthwir              0
# 240746               32kw generac protector seri\tgenerac              1
# 240747                               bathroom tap\tkohler              0
# 240748                  ceil fan light fixtur\tcasablanca              0
# 240749                                        peoni\tnull              0
# 240750                                 paracord\teverbilt              0
# 240751                     2 inch 1/4-20 bolt\tcrown bolt              1
# 240752                            bath chair\tunivers tub              0
# 240753                                1/2 brass\teverbilt              0
# 240754             pivot shower door\tcoastal shower door              2
# 240755                 24 whtie storag cabinet\tstufurhom              0
# 240756              adirondeck cusion\thome decor collect              0
# 240757                                           hb\tnull              0
# 240758                                   hex socket\tnull              0
# 240759                             4 inch hole saw\tbosch              0
#
#         ratio_brand
# 200000     0.000000
# 200001     0.000000
# 200002     0.500000
# 200003     0.000000
# 200004     0.000000
# 200005     0.000000
# 200006     0.000000
# 200007     0.000000
# 200008     0.000000
# 200009     0.000000
# 200010     0.000000
# 200011     0.000000
# 200012     0.000000
# 200013     0.000000
# 200014     0.000000
# 200015     0.000000
# 200016     1.000000
# 200017     0.000000
# 200018     0.000000
# 200019     0.000000
# 200020     0.000000
# 200021     0.000000
# 200022     0.500000
# 200023     0.000000
# 200024     0.000000
# 200025     0.000000
# 200026     0.000000
# 200027     0.000000
# 200028     1.000000
# 200029     0.000000
# ...             ...
# 240730     0.000000
# 240731     0.000000
# 240732     0.000000
# 240733     0.000000
# 240734     0.333333
# 240735     0.000000
# 240736     0.000000
# 240737     0.000000
# 240738     0.000000
# 240739     1.000000
# 240740     0.000000
# 240741     0.500000
# 240742     1.000000
# 240743     0.000000
# 240744     0.000000
# 240745     0.000000
# 240746     1.000000
# 240747     0.000000
# 240748     0.000000
# 240749     0.000000
# 240750     0.000000
# 240751     0.500000
# 240752     0.000000
# 240753     0.000000
# 240754     0.666667
# 240755     0.000000
# 240756     0.000000
# 240757     0.000000
# 240758     0.000000
# 240759     0.000000
#
# [40760 rows x 23 columns]

# %%
list(df_all)
# Out:
# ['id',
#  'product_title',
#  'product_uid',
#  'relevance',
#  'search_term',
#  'product_description',
#  'brand',
#  'len_of_query',
#  'len_of_title',
#  'len_of_description',
#  'len_of_brand',
#  'product_info',
#  'word_in_title',
#  'word_in_description',
#  'query_in_title',
#  'query_in_description',
#  'query_last_word_in_title',
#  'query_last_word_in_description',
#  'ratio_title',
#  'ratio_description',
#  'attr',
#  'word_in_brand',
#  'ratio_brand']

# %%
df_all = df_all.drop(['search_term','product_title','product_description','product_info','attr','brand'],axis=1)

# %%
df_train = df_all.iloc[:num_train]
df_test = df_all.iloc[num_train:]
id_test = df_test['id']

# %%
y_train = df_train['relevance'].values
X_train = df_train.drop(['id','relevance'],axis=1).values
X_test = df_test.drop(['id','relevance'],axis=1).values

# %%
rf = LinearRegression()

# %%
rf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = rf.predict(X_test)

# %%
pd.DataFrame({"id": id_test, "relevance": y_pred}).to_csv('linearRegressionSubmission.csv',index=False)
