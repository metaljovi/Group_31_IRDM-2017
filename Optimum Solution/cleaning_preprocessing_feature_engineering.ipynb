# %%
import re
import pandas as pd
import timeit
import nltk
import numpy as np
import string
from spell_check_dict import spelling_checker_dict
#stemmer = nltk.stem.porter.PorterStemmer()

# %%
#check you're in the right directory guys!
import os
os.getcwd()
# Out:
# '/Users/davida/Google Drive/IR & DM/IRDM Coursework'

# %%
import sys
sys.version
# Out:
# '3.5.2 |Anaconda custom (x86_64)| (default, Jul  2 2016, 17:52:12) \n[GCC 4.2.1 Compatible Apple LLVM 4.2 (clang-425.0.28)]'

# %%
#YOU NEED TO DOWNLOAD THE STOPWORDS BELOW - BUT THIS MIGHT IMPROVE THE SCORE
stop_words=nltk.corpus.stopwords.words('english')
strNum = {'zero':0,'one':1,'two':2,'three':3,'four':4,'five':5,'six':6,'seven':7,'eight':8,'nine':9}

# %%
a=timeit.default_timer()
df_train = pd.read_csv('train.csv',encoding="ISO-8859-1")
df_test = pd.read_csv('test.csv',encoding="ISO-8859-1")
df_pro_desc = pd.read_csv('product_descriptions.csv')
df_attr = pd.read_csv('attributes.csv')
df_all = pd.concat((df_train, df_test), axis=0, ignore_index=True)
df_all = pd.merge(df_all, df_pro_desc, how='left', on='product_uid')
len_train = df_train.shape[0]
b=timeit.default_timer()
print('loading and merging took {}s'.format(b-a))
# Out:
# loading and merging took 6.080197404953651s

# %%
#check what is actually missing
df_attr[df_attr.isnull().any(axis=1)]

#we see that for some attributes, values are missing, so these attributes become useless

before_len_df_attr=len(df_attr)
df_attr.dropna(inplace=True)
print('removed {} rows from df_attr'.format(before_len_df_attr-len(df_attr)))
# Out:
# removed 2090 rows from df_attr

# %%
from sklearn.utils import shuffle as sklearn_shuffle
a=timeit.default_timer()
df_train=sklearn_shuffle(df_train,random_state=2017)
b=timeit.default_timer()
print('shuffling train data took {}s'.format(b-a))
# Out:
# shuffling train data took 0.04189527401467785s

# %%
#PREPROCESSING PIPELINE
def unit_converter(s):
    try:
        #replace units
        s=re.sub(r"([0-9]+)( *)(inches|inch|in|in.|')\.?", r"\1 in. ",s)
        s=re.sub(r"([0-9]+)( *)(pounds|pound|lbs|lb|lb.)\.?", r"\1 lb. ",s)
        s=re.sub(r"([0-9]+)( *)(foot|feet|ft|ft.|'')\.?", r"\1 ft. ",s)
        s=re.sub(r"([0-9]+)( *)(square|sq|sq.) ?\.?(inches|inch|in|in.|')\.?", r"\1 sq.in. ",s)
        s=re.sub(r"([0-9]+)( *)(square|sq|sq.) ?\.?(feet|foot|ft|ft.|'')\.?", r"\1 sq.ft. ",s)
        s=re.sub(r"([0-9]+)( *)(cubic|cu|cu.) ?\.?(inches|inch|in|in.|')\.?", r"\1 cu.in. ", s)
        s=re.sub(r"([0-9]+)( *)(cubic|cu|cu.) ?\.?(feet|foot|ft|ft.|'')\.?", r"\1 cu.ft. ", s)
        s=re.sub(r"([0-9]+)( *)(gallons|gallon|gal)\.?", r"\1 gal. ",s)
        s=re.sub(r"([0-9]+)( *)(ounces|ounce|oz)\.?", r"\1 oz. ",s)
        s=re.sub(r"([0-9]+)( *)(centimeters|cm)\.?", r"\1 cm. ",s)
        s=re.sub(r"([0-9]+)( *)(milimeters|mm)\.?", r"\1 mm. ",s)
        s=re.sub(r"([0-9]+)( *)(minutes|minute)\.?", r"\1 min. ",s)
        s=re.sub(r"([0-9]+)( *)(°|degrees|degree)\.?", r"\1 deg. ",s)
        s=re.sub(r"([0-9]+)( *)(v|volts|volt)\.?", r"\1 volt. ",s)
        s=re.sub(r"([0-9]+)( *)(wattage|watts|watt)\.?", r"\1 watt. ",s)
        s=re.sub(r"([0-9]+)( *)(amperes|ampere|amps|amp)\.?", r"\1 amp. ",s)
        s=re.sub(r"([0-9]+)( *)(qquart|quart)\.?", r"\1 qt. ",s)
        s=re.sub(r"([0-9]+)( *)(hours|hour|hrs.)\.?", r"\1 hr ",s)
        s=re.sub(r"([0-9]+)( *)(gallons per minute|gallon per minute|gal per minute|gallons/min.|gallons/min)\.?", \
         r"\1 gal. per min. ",s)
        s=re.sub(r"([0-9]+)( *)(gallons per hour|gallon per hour|gal per hour|gallons/hour|gallons/hr)\.?", r"\1 gal. per hr ",s)
        
        #replace things like '3x4 mm' or '3 by 4 mm' with '3 xbi 4'
        s = s.replace(" x "," xbi ")
        s = s.replace("*"," xbi ")
        s = s.replace(" by "," xbi ")
        s = s.replace('<b>','')
        s = s.replace('</b>','')
        s = s.replace('<br>','')
        s = s.replace('</br>','')
        #replace random weird stuff found after manual inspection
        s = s.replace('_',' ')
        s = s.replace('..','.')
        s = s.replace('\\',' ')
        s = s.replace('/',' ')
        s = s.replace('  ', ' ')
        s = s.replace('  ', ' ')
    except:
        raise TypeError(s,' is not a string')
    return s
def uppercase_splitter(s):
    #e.g. concrete surfaceActual to concrete surface Actual
    try:
        s=re.sub(r"(\w)[\.?!]([A-Z])", r"\1 \2",s)
        s=re.sub(r"(?<=( ))([a-z]+)([A-Z]+)", r"\2 \3",s)
        return s
    except:
        raise TypeError(s, 'is not a string')
def letter_splitter(s):
    #handles hyphens
    #e.g. pressure-treated to pressure treated, but keeps the the digits in place
    #e.g. sink strainer 3-1/2 to sink strainer 3-1/2
    try:
        s=re.sub(r"([a-zA-Z]+)[/\-]([a-zA-Z]+)", r"\1 \2",s)
        return s
    except:
        raise TypeError(s, 'is not a string')
        
def digit_comma_merger(s):
    #'2,000' to 2000
    try:
        s=re.sub(r"(?<=\d),(?=000)", r"",s)
        return s
    except:
        raise TypeError(s, 'is not a string')

def digit_letter_splitter(s):
    # 3x4x5 to 3 x 4 x 5
    try:
        s=re.sub(r"(\d+)[\.\-]*([a-zA-Z]+)", r"\1 \2",s)
        return s
    except:
        raise TypeError(s, 'is not a string')
    
def string_digit_mapper(s):
    #HANDLES ONLY TWO DIGIT NUMBERS (not 'three hundred ten')
    #produces gibberish otherwise
    #twenty three to 23
    #fourteen to 14
    numbers={'zero': '0','one': '1','two': '2', 'three': '3','four': '4',
             'five': '5','six': '6','seven': '7','eight': '8','nine': '9',
             'ten': '10', 'eleven': '11', 'twelve': '12', 'thirteen': '13',
             'fourteen': '14','fifteen': '15','sixteen': '16','seventeen': '17',
             'eighteen': '18', 'nineteen': '19','twenty': '20','thirty': '30',
             'forty': '40', 'fifty': '50','sixty': '60', 'seventy': '70',
              'eighty': '80','ninety': '90'}
    stop_numbers={'hundred':'100','thousand':'1000','million':'1000000'}
    
    r=s.split(' ')
    for ind, word in enumerate(r):
        if word in numbers:
            try:
                next_word=r[ind+1]
                if next_word in numbers and next_word not in stop_numbers:
                    try:
                        next_next_word=r[ind+2]
                        if next_next_word in numbers or next_next_word in stop_numbers:
                            return s
                        s=s.replace(word+' ','')
                        s=s.replace(word,'')
                        s=s.replace(next_word,numbers[word][0]+numbers[next_word])
                        return s

                    except:
                        s=s.replace(word+' ','')
                        s=s.replace(word,'')
                        s=s.replace(next_word,numbers[word][0]+numbers[next_word])
                        return s
                

            except:
                s=s.replace(word,numbers[word])
                return s
    return s


def lemmatiser(tokeniser=nltk.tokenize.TreebankWordTokenizer(),lemmatizer=nltk.stem.wordnet.WordNetLemmatizer()):
    
    return lambda x: " ".join(lemmatizer.lemmatize(token) for token in tokeniser.tokenize(x) if token not in stop_words)

def stemmer(tokeniser=nltk.tokenize.TreebankWordTokenizer(),lemmatizer=nltk.stem.SnowballStemmer('english')):
    #WARNING - LEMMATISER SHOULD BE THEORETICALLY BETTER

    return lambda x: " ".join(stemmer.stem(token) for token in tokeniser.tokenize(x) if token not in stop_words)

def strip_punctuation(tokeniser=nltk.tokenize.TreebankWordTokenizer()):
    #remove all punctuation (needed for product description) except for dots
    return lambda x: x.translate({ord(c): None for c in string.punctuation if c!='.'})
    #return lambda x: ' '.join(token for token in tokeniser.tokenize(x) if token not in stop_words)

def preprocessor():
        #THE ORDER IS FROM BOTTOM TO TOP (i.e. starting with x.lower())
    return lambda x:unit_converter(\
            string_digit_mapper(\
            digit_comma_merger(\
            digit_letter_splitter(\
            letter_splitter(\
            uppercase_splitter(\
            x.lower()
                                      )
                                          )
                                               )
                                                     )
                                                          )
                                                              )
def spell_checker():
        return lambda x:spelling_checker_dict[x] if x in spelling_checker_dict else x                                             

tokeniser = nltk.tokenize.TreebankWordTokenizer()
lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
stemmer=nltk.stem.SnowballStemmer('english')

# %%
a=timeit.default_timer()
#don't know why two spell checkers - just to be safe I guess?
df_all['search_term']=df_all['search_term'].apply(spell_checker())
df_all['search_term']=df_all['search_term'].apply(preprocessor())
df_all['search_term']=df_all['search_term'].apply(spell_checker())
df_all['search_term']=df_all['search_term'].apply(lemmatiser())
b=timeit.default_timer()
print('preprocessing search term took {}s'.format(b-a))

a=timeit.default_timer()
df_all['product_title'] = df_all['product_title'].apply(preprocessor())
df_all['product_title'] = df_all['product_title'].apply(lemmatiser())
b=timeit.default_timer()
print('preprocessing product title took {}s'.format(b-a))

a=timeit.default_timer()
df_all['product_description'] = df_all['product_description'].apply(preprocessor())
df_all['product_description'] = df_all['product_description'].apply(lemmatiser())
b=timeit.default_timer()
print('preprocessing product description took {}s'.format(b-a))
# Out:
# preprocessing search term took 45.839277692954056s
# preprocessing product title took 79.15371667803265s
# preprocessing product description took 556.2166322790436s

# %%
#look for colour attributes
a=timeit.default_timer()

attr_names=df_attr.name.unique().tolist()
colour_names=[] #a list of unique colour attribute names
for name in attr_names:
    if type(name)==str:
        if 'Color' in name:
            colour_names.append(name)
      
            
df_colour = df_attr[df_attr.name.isin(colour_names)][["product_uid", "value"]]
df_colour.columns.values[1]='product_colour'

df_aggr_colour=df_colour.groupby(['product_uid'],as_index=False).aggregate(lambda x: ' '.join(list(set(x))))
#print(df_aggr_colour['product_uid'])
df_aggr_colour['product_colour']=df_aggr_colour['product_colour'].apply(lambda x: ' '.join(list(set(x.split()))))
df_aggr_colour['product_colour']=df_aggr_colour['product_colour'].apply(lambda x: unit_converter(x.lower()))
df_aggr_colour['product_colour']=df_aggr_colour['product_colour'].apply(lemmatiser())

b=timeit.default_timer()
print('preprocessing colour took {}s'.format(b-a))


a=timeit.default_timer()

df_brand = df_attr[df_attr.name == "MFG Brand Name"][["product_uid", "value"]]
df_brand.columns.values[1]='brand' #renaming
df_brand['brand']=df_brand['brand'].apply(lambda x: x.lower())
df_brand['brand']= df_brand['brand'].apply(lemmatiser())

b=timeit.default_timer()
print('preprocessing brand took {}s'.format(b-a))


a=timeit.default_timer()

df_product_weight=df_attr[df_attr.name=='Product Weight (lb.)'][["product_uid", "value"]]
df_product_weight.columns.values[1]='product_weight'
df_product_weight['product_weight']=df_product_weight['product_weight'].apply(lambda x: unit_converter(x.lower()))
df_product_weight['product_weight']=df_product_weight['product_weight'].apply(lemmatiser())

df_product_depth=df_attr[df_attr.name=='Product Depth (in.)'][["product_uid", "value"]]
df_product_depth.columns.values[1]='product_depth'

df_product_depth['product_depth']=df_product_depth['product_depth'].apply(lambda x: unit_converter(x.lower()))
df_product_depth['product_depth']=df_product_depth['product_depth'].apply(lemmatiser())

df_product_height=df_attr[df_attr.name=='Product Height (in.)'][["product_uid", "value"]]
df_product_height.columns.values[1]='product_height'
df_product_height['product_height']=df_product_height['product_height'].apply(lambda x: unit_converter(x.lower()))
df_product_height['product_height']=df_product_height['product_height'].apply(lemmatiser())


df_product_width=df_attr[df_attr.name=='Product Width (in.)'][["product_uid", "value"]]
df_product_width.columns.values[1]='product_width'
df_product_width['product_width']=df_product_width['product_width'].apply(lambda x: unit_converter(x.lower()))
df_product_width['product_width']=df_product_width['product_width'].apply(lemmatiser())

b=timeit.default_timer()

print('preprocessing size took {}s'.format(b-a))

a=timeit.default_timer()
#ONLY FIRST 5 BULLET POINTS 
df_bullets_01=df_attr[df_attr.name=='Bullet01'][['product_uid','value']]
df_bullets_01.columns.values[1]='Bullet01'
df_bullets_01['Bullet01']=df_bullets_01['Bullet01'].apply(lambda x: unit_converter(x.lower()))
df_bullets_01['Bullet01']=df_bullets_01['Bullet01'].apply(lemmatiser())

df_bullets_02=df_attr[df_attr.name=='Bullet02'][['product_uid','value']]
df_bullets_02.columns.values[1]='Bullet02'
df_bullets_02['Bullet02']=df_bullets_02['Bullet02'].apply(lambda x: unit_converter(x.lower()))
df_bullets_02['Bullet02']=df_bullets_02['Bullet02'].apply(lemmatiser())

df_bullets_03=df_attr[df_attr.name=='Bullet03'][['product_uid','value']]
df_bullets_03.columns.values[1]='Bullet03'
df_bullets_03['Bullet03']=df_bullets_03['Bullet03'].apply(lambda x: unit_converter(x.lower()))
df_bullets_03['Bullet03']=df_bullets_03['Bullet03'].apply(lemmatiser())

df_bullets_04=df_attr[df_attr.name=='Bullet04'][['product_uid','value']]
df_bullets_04.columns.values[1]='Bullet04'
df_bullets_04['Bullet04']=df_bullets_04['Bullet04'].apply(lambda x: unit_converter(x.lower()))
df_bullets_04['Bullet04']=df_bullets_04['Bullet04'].apply(lemmatiser())

df_bullets_05=df_attr[df_attr.name=='Bullet05'][['product_uid','value']]
df_bullets_05.columns.values[1]='Bullet05'
df_bullets_05['Bullet05']=df_bullets_05['Bullet05'].apply(lambda x: unit_converter(x.lower()))
df_bullets_05['Bullet05']=df_bullets_05['Bullet05'].apply(lemmatiser())
b=timeit.default_timer()

print('preprocessing bulletpoints took {}s'.format(b-a))
# Out:
# preprocessing colour took 10.890548886964098s
# preprocessing brand took 6.5050218279939145s
# preprocessing size took 26.90326750598615s
# preprocessing bulletpoints took 99.93677522300277s

# %%
df_unmerged=pd.read_csv('raw_unmerged.csv')
df_unmerged.head()
# Out:
#    Unnamed: 0  id                                      product_title  \
# 0           0   2                  simpson strong tie 12 gauge angle
# 1           1   3                  simpson strong tie 12 gauge angle
# 2           2   9  behr premium textured deckover 1 gal. # sc-141...
# 3           3  16  delta vero 1 handle shower faucet trim kit chr...
# 4           4  17  delta vero 1 handle shower faucet trim kit chr...
#
#    product_uid  relevance       search_term  \
# 0       100001       3.00     angle bracket
# 1       100001       2.50         l bracket
# 2       100002       3.00              deck
# 3       100005       2.33  rain shower head
# 4       100005       2.67     shower faucet
#
#                                  product_description
# 0  angle make joint stronger , also provide consi...
# 1  angle make joint stronger , also provide consi...
# 2  behr premium textured deckover innovative soli...
# 3  update bathroom delta vero single handle showe...
# 4  update bathroom delta vero single handle showe...

# %%
df_try = pd.merge(df_unmerged, df_aggr_colour, how='left', on='product_uid')
df_try = pd.merge(df_try, df_brand, how='left', on='product_uid')
df_try = pd.merge(df_try, df_product_weight, how='left', on='product_uid')
df_try = pd.merge(df_try, df_product_depth, how='left', on='product_uid')
df_try = pd.merge(df_try, df_product_height, how='left', on='product_uid')
df_try = pd.merge(df_try, df_product_width, how='left', on='product_uid')
df_try = pd.merge(df_try, df_bullets_01, how='left', on='product_uid')
df_try = pd.merge(df_try, df_bullets_02, how='left', on='product_uid')
df_try = pd.merge(df_try, df_bullets_03, how='left', on='product_uid')
df_try = pd.merge(df_try, df_bullets_04, how='left', on='product_uid')
df_try = pd.merge(df_try, df_bullets_05, how='left', on='product_uid')

# %%
#df_try.to_csv('raw.csv',index=False)

df_all=pd.read_csv('raw.csv')

#df_all=df_try
df_all.search_term=df_all.search_term.replace(np.nan, '')
df_all[df_all.product_colour.isnull()]
# Out:
#         Unnamed: 0      id                                      product_title  \
# 0                0       2                  simpson strong tie 12 gauge angle
# 1                1       3                  simpson strong tie 12 gauge angle
# 11              11      35  toro personal pace recycler 22 in. variable sp...
# 12              12      37  toro personal pace recycler 22 in. variable sp...
# 13              13      38  toro personal pace recycler 22 in. variable sp...
# 17              17      69  md building product 36 in. xbi 36 in. cloverle...
# 18              18      75  md building product 36 in. xbi 36 in. cloverle...
# 19              19      81  md building product 36 in. xbi 36 in. cloverle...
# 20              20      85  md building product 36 in. xbi 36 in. cloverle...
# 37              37     143       ultratouch 48 in. xbi 24 ft. radiant barrier
# 47              47     172  hdx 48 in. w xbi 72 in. h xbi 18 in. decorativ...
# 48              48     177  hdx 48 in. w xbi 72 in. h xbi 18 in. decorativ...
# 49              49     178  hdx 48 in. w xbi 72 in. h xbi 18 in. decorativ...
# 50              50     179  hdx 48 in. w xbi 72 in. h xbi 18 in. decorativ...
# 51              51     181  hdx 48 in. w xbi 72 in. h xbi 18 in. decorativ...
# 52              52     182  hdx 48 in. w xbi 72 in. h xbi 18 in. decorativ...
# 53              53     186  hdx 48 in. w xbi 72 in. h xbi 18 in. decorativ...
# 54              54     191  hdx 48 in. w xbi 72 in. h xbi 18 in. decorativ...
# 55              55     193  hdx 48 in. w xbi 72 in. h xbi 18 in. decorativ...
# 56              56     195                         marshalltown masonry brush
# 64              64     223  emberglow 25000 btu vent free dual fuel gas st...
# 65              65     226  emberglow 25000 btu vent free dual fuel gas st...
# 66              66     227  emberglow 25000 btu vent free dual fuel gas st...
# 67              67     233  emberglow 25000 btu vent free dual fuel gas st...
# 70              70     255  sumner street home hardware grayson 2-1 2 in. ...
# 76              76     272  crown bolt 24 in. xbi 1 2 in. xbi 12 in. plain...
# 77              77     275  crown bolt 24 in. xbi 1 2 in. xbi 12 in. plain...
# 78              78     276  crown bolt 24 in. xbi 1 2 in. xbi 12 in. plain...
# 84              84     305                    60 in. xbi 150 ft. 10 10 remesh
# 93              93     340       bare ground 4 gal. liquid de icer ( case-4 )
# ...            ...     ...                                                ...
# 240677      240677  240678                 century 1 2 hp condenser fan motor
# 240681      240681  240682  upper bounce trampoline enclosure set fit 13 f...
# 240684      240684  240685              woolite 32 oz. pet stain odor remover
# 240686      240686  240687  hanover lime green weather adirondack patio ch...
# 240687      240687  240688   durham & # 39 ; rock hard du-1 1 lb. water putty
# 240688      240688  240689  formufit 3 4 in. furniture grade pvc external ...
# 240691      240691  240692                stamen elliptical trainer handlebar
# 240695      240695  240696            polywood nautical black patio bar chair
# 240696      240696  240697  weatherables vilano 36 in. xbi 48 in. vinyl wh...
# 240699      240699  240700  charlotte pipe 8 in. xbi 8 in. xbi 6 in. pvc d...
# 240707      240707  240708  home decorator collection 36 in. xbi 36 in. & ...
# 240709      240709  240710      18 in. tabletop tree topper angel burlap gown
# 240711      240711  240712              smart spa vinyl spa step discontinued
# 240715      240715  240716  amflo 3 8 in. xbi 50 ft. pvc rubber blend air ...
# 240718      240718  240719  celestron element infinisun portable power pac...
# 240719      240719  240720   safavieh mischa ash grey acacia wood patio bench
# 240724      240724  240725  cerro 1 4 in. lead free brass 90 deg. fpt xbi ...
# 240726      240726  240727  superwinch 8000 lb. pulley block hook ex1 , x1...
# 240728      240728  240729  amflo 1 4 in. xbi 50 ft. polyurethane air hose...
# 240731      240731  240732    eaton csr 200 amp. double pole main breaker kit
# 240732      240732  240733  crown bolt 3 16 in. zinc plated steel axle hat...
# 240738      240738  240739        kwikset milan satin nickel half dummy lever
# 240739      240739  240740  advanced drainage system 1 2 in. xbi 100 ft. i...
# 240740      240740  240741  magnavox 50 in. class led 1080 p 120 bmr slim ...
# 240742      240742  240743  minwax 1 gal. semi gloss polycrylic protective...
# 240749      240749  240750  glidden premium 5 gal. # hdgr19 fresh peony sa...
# 240753      240753  240754  everbilt # 12 xbi 1-1 2 in. phillips brass fla...
# 240754      240754  240755  coastal shower door legend series 24 in. xbi 6...
# 240757      240757  240758  simpson strong tie hb 3-1 2 xbi 14 in. top fla...
# 240758      240758  240759  1 4 in. -20 tpi xbi 1-1 2 in. stainless steel ...
#
#         product_uid  relevance  \
# 0            100001       3.00
# 1            100001       2.50
# 11           100011       3.00
# 12           100011       3.00
# 13           100011       2.00
# 17           100017       1.00
# 18           100017       1.67
# 19           100017       2.33
# 20           100017       2.33
# 37           100027       2.33
# 47           100033       3.00
# 48           100033       3.00
# 49           100033       1.00
# 50           100033       3.00
# 51           100033       2.67
# 52           100033       2.67
# 53           100033       3.00
# 54           100033       2.67
# 55           100033       3.00
# 56           100034       1.00
# 64           100039       2.33
# 65           100039       2.33
# 66           100039       2.33
# 67           100039       3.00
# 70           100045       2.33
# 76           100047       3.00
# 77           100047       2.33
# 78           100047       3.00
# 84           100053       3.00
# 93           100056       1.33
# ...             ...        ...
# 240677       224346        NaN
# 240681       224350        NaN
# 240684       224353        NaN
# 240686       224355        NaN
# 240687       224356        NaN
# 240688       224357        NaN
# 240691       224360        NaN
# 240695       224364        NaN
# 240696       224365        NaN
# 240699       224368        NaN
# 240707       224376        NaN
# 240709       224378        NaN
# 240711       224380        NaN
# 240715       224384        NaN
# 240718       224387        NaN
# 240719       224388        NaN
# 240724       224393        NaN
# 240726       224395        NaN
# 240728       224397        NaN
# 240731       224400        NaN
# 240732       224401        NaN
# 240738       224407        NaN
# 240739       224408        NaN
# 240740       224409        NaN
# 240742       224411        NaN
# 240749       224418        NaN
# 240753       224422        NaN
# 240754       224423        NaN
# 240757       224426        NaN
# 240758       224427        NaN
#
#                                            search_term  \
# 0                                        angle bracket
# 1                                            l bracket
# 11                          briggs stratton lawn mower
# 12                                           gas mower
# 13                                         honda mower
# 17                                          door guard
# 18                              metal plate cover gfci
# 19                                      radiator grate
# 20                                       window screen
# 37                                     insulation roll
# 47                                     6 tier shelving
# 48                                   hdx wire shelving
# 49                              kitchen cabinet finish
# 50                           kitchen wire shelf tiered
# 51                                         pantry rack
# 52                                plastic storage rack
# 53                                         shelf metal
# 54                                      steel shelving
# 55                                       storage shelf
# 56                                         mortar tool
# 64                                        pellet stove
# 65                                       register fuel
# 66                                            stove mi
# 67                                  ventless gas stove
# 70                                             grayson
# 76                                 bolt 1 2 in. xbi 12
# 77                                         metal sheet
# 78                                         sheet metal
# 84                                            wiremesh
# 93                                         roof melter
# ...                                                ...
# 240677                    ao smith condenser fan motor
# 240681                                      round pole
# 240684                           granite stain remover
# 240686                        adirondack , patio chair
# 240687                                          durham
# 240688                                     3 4 pvc cap
# 240691                                      elliptical
# 240695                               bar chair armrest
# 240696                       4 ft. claissic rail white
# 240699                                       6 in. tee
# 240707                                           dreme
# 240709                           christmas tree topper
# 240711                                        spa step
# 240715                                         airhose
# 240718                                         camping
# 240719                            outdoor wooden bench
# 240724  3 4 in. x3 4 in. lead free brass 45 deg. elbow
# 240726                                    pulley block
# 240728                                 compressor hose
# 240731                    200 amp. breaker double pole
# 240732                                axle locking nut
# 240738                                    dummy handle
# 240739                        advanced drainage system
# 240740                                          led tv
# 240742                               minwax polycrylic
# 240749                                           peony
# 240753                                       1 2 brass
# 240754                               pivot shower door
# 240757                                              hb
# 240758                                      hex socket
#
#                                       product_description product_colour  \
# 0       angle make joint stronger , also provide consi...            NaN
# 1       angle make joint stronger , also provide consi...            NaN
# 11      recycler 22 in. personal pace variable speed s...            NaN
# 12      recycler 22 in. personal pace variable speed s...            NaN
# 13      recycler 22 in. personal pace variable speed s...            NaN
# 17      md building product 36 in. xbi 36 in. xbi 1 50...            NaN
# 18      md building product 36 in. xbi 36 in. xbi 1 50...            NaN
# 19      md building product 36 in. xbi 36 in. xbi 1 50...            NaN
# 20      md building product 36 in. xbi 36 in. xbi 1 50...            NaN
# 37      ultratouch 48 in. xbi 24 ft. radiant barrier e...            NaN
# 47      easy to-assemble decorative wire chrome finish...            NaN
# 48      easy to-assemble decorative wire chrome finish...            NaN
# 49      easy to-assemble decorative wire chrome finish...            NaN
# 50      easy to-assemble decorative wire chrome finish...            NaN
# 51      easy to-assemble decorative wire chrome finish...            NaN
# 52      easy to-assemble decorative wire chrome finish...            NaN
# 53      easy to-assemble decorative wire chrome finish...            NaN
# 54      easy to-assemble decorative wire chrome finish...            NaN
# 55      easy to-assemble decorative wire chrome finish...            NaN
# 56      use marshalltown masonry brush wide variety ta...            NaN
# 64      emberglow vent free gas stove help add warmth ...            NaN
# 65      emberglow vent free gas stove help add warmth ...            NaN
# 66      emberglow vent free gas stove help add warmth ...            NaN
# 67      emberglow vent free gas stove help add warmth ...            NaN
# 70      grayson collection thomasville brings customiz...            NaN
# 76      expanded sheet metal altered shape cut proper ...            NaN
# 77      expanded sheet metal altered shape cut proper ...            NaN
# 78      expanded sheet metal altered shape cut proper ...            NaN
# 84      60 in. xbi 150 ft. 10 10 remesh provides expan...            NaN
# 93      bare ground liquid deicer environmentally frie...            NaN
# ...                                                   ...            ...
# 240677  ao smith 1 3 hp 208 230 volt. olt 1 ph single ...            NaN
# 240681  trampoline enclosure set must ensure maximum s...            NaN
# 240684  woolite 32 fl. oz. pet plus oxygen stain odor ...            NaN
# 240686  enjoy complete comfort relaxation weather adir...            NaN
# 240687  80 year , durham rock hard water putty making ...            NaN
# 240688  add flat , smooth end structural pvc applicati...            NaN
# 240691  stamen inmotion elliptical trainer affordable ...            NaN
# 240695  grab cold drink make comfortable polywood naut...            NaN
# 240696  surround home strong , durable vilano vinyl ra...            NaN
# 240699  pvc fitting drain , waste vent purposes. used ...            NaN
# 240707  idyllic farm scene country dream wall art add ...            NaN
# 240709  soft burlap gown feathery white wing , beautif...            NaN
# 240711  two toned spa side step taken durability , sty...            NaN
# 240715  rubber pvc blend air hose ideal general purpos...            NaN
# 240718  celestrons innovative infinisun solar panel ch...            NaN
# 240719  stop smell roses. mischa bench crafted dark gr...            NaN
# 240724  project benefit long lasting connection pipe f...            NaN
# 240726  superwinch 8000 lb. pulley block hook designed...            NaN
# 240728  light weight polyurethane hose make ideal appl...            NaN
# 240731  eaton csr 200 amp. double pole main breaker ki...            NaN
# 240732  push nut screw thread inward facing flange. fl...            NaN
# 240738  step designer style superior security kwikset ...            NaN
# 240739  1 2 in. xbi 100 ft. ip 125 psi nsf poly pipe e...            NaN
# 240740  enjoy optimal viewing area magnavox 50 in. 108...            NaN
# 240742  minwax polycrylic protective finish protective...            NaN
# 240749  glidden premium 5 gal. satin latex exterior pa...            NaN
# 240753  wood screw thread forming screw larger thread ...            NaN
# 240754  legend series framed swing stand alone continu...            NaN
# 240757  joist hanger designed provide support undernea...            NaN
# 240758  socket cap screw ideal application require wel...            NaN
#
#                               brand product_weight product_depth  \
# 0                simpson strong-tie           0.26           1.5
# 1                simpson strong-tie           0.26           1.5
# 11                             toro             80           NaN
# 12                             toro             80           NaN
# 13                             toro             80           NaN
# 17              md building product     1.188 lb .          0.02
# 18              md building product     1.188 lb .          0.02
# 19              md building product     1.188 lb .          0.02
# 20              md building product     1.188 lb .          0.02
# 37                       ultratouch             16           NaN
# 47                              hdx            NaN           NaN
# 48                              hdx            NaN           NaN
# 49                              hdx            NaN           NaN
# 50                              hdx            NaN           NaN
# 51                              hdx            NaN           NaN
# 52                              hdx            NaN           NaN
# 53                              hdx            NaN           NaN
# 54                              hdx            NaN           NaN
# 55                              hdx            NaN           NaN
# 56                     marshalltown            NaN          1.75
# 64                        emberglow           51.2            13
# 65                        emberglow           51.2            13
# 66                        emberglow           51.2            13
# 67                        emberglow           51.2            13
# 70      sumner street home hardware            NaN           NaN
# 76                       crown bolt           1.64           0.5
# 77                       crown bolt           1.64           0.5
# 78                       crown bolt           1.64           0.5
# 84                        unbranded            150          0.25
# 93                      bare ground            NaN            12
# ...                             ...            ...           ...
# 240677                      century          18.05          13.1
# 240681                 upper bounce             42           NaN
# 240684                      woolite            NaN           NaN
# 240686                      hanover             48           NaN
# 240687          durham 's rock hard           1.11             3
# 240688                     formufit            0.1             1
# 240691                       stamen            NaN           NaN
# 240695                     polywood             35           NaN
# 240696                          NaN            NaN           NaN
# 240699               charlotte pipe         16.598        156.88
# 240707    home decorator collection             18             2
# 240709                    unbranded            NaN            12
# 240711                    smart spa             22            25
# 240715                        amflo              5           NaN
# 240718                    celestron             .5             1
# 240719                     safavieh           54.9           NaN
# 240724                        cerro            .12           1.5
# 240726                   superwinch              2           8.5
# 240728                        amflo              3           NaN
# 240731                        eaton           2.55         3.215
# 240732                   crown bolt         0.0393           NaN
# 240738                      kwikset              1           NaN
# 240739     advanced drainage system             32             5
# 240740                     magnavox            NaN           NaN
# 240742                       minwax            NaN           NaN
# 240749                          NaN            NaN           NaN
# 240753                     everbilt         0.0287           NaN
# 240754          coastal shower door             65           NaN
# 240757                          NaN            NaN           NaN
# 240758                          NaN            NaN           NaN
#
#        product_height product_width  \
# 0                   3             3
# 1                   3             3
# 11                NaN           NaN
# 12                NaN           NaN
# 13                NaN           NaN
# 17                 36          36 .
# 18                 36          36 .
# 19                 36          36 .
# 20                 36          36 .
# 37                NaN           NaN
# 47                NaN           NaN
# 48                NaN           NaN
# 49                NaN           NaN
# 50                NaN           NaN
# 51                NaN           NaN
# 52                NaN           NaN
# 53                NaN           NaN
# 54                NaN           NaN
# 55                NaN           NaN
# 56             11.875           6.5
# 64                 25          35.4
# 65                 25          35.4
# 66                 25          35.4
# 67                 25          35.4
# 70                NaN           NaN
# 76                 12            12
# 77                 12            12
# 78                 12            12
# 84                 60          1800
# 93                 12            12
# ...               ...           ...
# 240677            7.4           6.8
# 240681             71           156
# 240684            NaN           NaN
# 240686            NaN           NaN
# 240687           5.63             3
# 240688            0.6             1
# 240691           49.5         18.75
# 240695            NaN           NaN
# 240696            NaN           NaN
# 240699          15.33         8.655
# 240707             36            36
# 240709             18            12
# 240711             16          32.5
# 240715            NaN           NaN
# 240718              7             5
# 240719            NaN           NaN
# 240724              1          .375
# 240726              1             5
# 240728            NaN           NaN
# 240731          6.122         2.741
# 240732            NaN           NaN
# 240738            NaN           NaN
# 240739             50            50
# 240740            NaN           NaN
# 240742            NaN           NaN
# 240749            NaN           NaN
# 240753            NaN           NaN
# 240754            NaN           NaN
# 240757            NaN           NaN
# 240758            NaN           NaN
#
#                                                  Bullet01  \
# 0       versatile connector various 90 deg. connection...
# 1       versatile connector various 90 deg. connection...
# 11      recycler cutting system - front throw chamber ...
# 12      recycler cutting system - front throw chamber ...
# 13      recycler cutting system - front throw chamber ...
# 17      use repair door window screen , add stylish ac...
# 18      use repair door window screen , add stylish ac...
# 19      use repair door window screen , add stylish ac...
# 20      use repair door window screen , add stylish ac...
# 37      reflects 97 % radiant energy , reducing heatin...
# 47      shelf support 600 lb. evenly distributed ; tot...
# 48      shelf support 600 lb. evenly distributed ; tot...
# 49      shelf support 600 lb. evenly distributed ; tot...
# 50      shelf support 600 lb. evenly distributed ; tot...
# 51      shelf support 600 lb. evenly distributed ; tot...
# 52      shelf support 600 lb. evenly distributed ; tot...
# 53      shelf support 600 lb. evenly distributed ; tot...
# 54      shelf support 600 lb. evenly distributed ; tot...
# 55      shelf support 600 lb. evenly distributed ; tot...
# 56                       bristle made white tampico fiber
# 64      automatic thermostat set desired heat output s...
# 65      automatic thermostat set desired heat output s...
# 66      automatic thermostat set desired heat output s...
# 67      automatic thermostat set desired heat output s...
# 70      2-1 2 in. center center measurement , 4-13 32 ...
# 76                                                1-piece
# 77                                                1-piece
# 78                                                1-piece
# 84      provides expansion contraction reinforcement c...
# 93                                            all-natural
# ...                                                   ...
# 240677                                           1075 rpm
# 240681  enclosure set includes : high quality 13 ft. e...
# 240684                eliminates pet stain offensive odor
# 240686  contoured design hideaway ottoman comfortable ...
# 240687                          stick stay - putty shrink
# 240688  made ultra-strong , uv-resistant furniture gra...
# 240691  adjustable tension control workout intensity l...
# 240695        eco-friendly product made recycled material
# 240696                                                NaN
# 240699  conforms meet standard : astm 1784 , astm 2665...
# 240707              print original work xbi michael longo
# 240709  versatile angel figure perfect treetop table c...
# 240711                    maintenance free molded plastic
# 240715  3 8 in. xbi 50 ft. rubber pvc blend air hose 1...
# 240718  6000 mah lithium battery charge iphone , ipad ...
# 240719        acacia wood provides rustic look patio deck
# 240724                      solid brass superior strength
# 240726                              change direction pull
# 240728  1 4 in. xbi 50 ft. polyurethane air hose 1 4 i...
# 240731  use main breaker main breaker meter breaker lo...
# 240732                                  3-pieces per pack
# 240738  designer style superior security kwikset signa...
# 240739  flexible construction installs ease uneven ter...
# 240740       spectacular picture full hd 1080p resolution
# 240742  crystal clear finish ideal use light wood like...
# 240749                                                NaN
# 240753                                   2 piece per pack
# 240754  adjusts fit shower opening minimum width dimen...
# 240757                                                NaN
# 240758                                                NaN
#
#                                                  Bullet02  \
# 0           stronger angled nailing screw fastening alone
# 1           stronger angled nailing screw fastening alone
# 11                         22 in. steel deck atomic blade
# 12                         22 in. steel deck atomic blade
# 13                         22 in. steel deck atomic blade
# 17                        lightweight sturdy construction
# 18                        lightweight sturdy construction
# 19                        lightweight sturdy construction
# 20                        lightweight sturdy construction
# 37                                       easy use install
# 47                            tool required easy assembly
# 48                            tool required easy assembly
# 49                            tool required easy assembly
# 50                            tool required easy assembly
# 51                            tool required easy assembly
# 52                            tool required easy assembly
# 53                            tool required easy assembly
# 54                            tool required easy assembly
# 55                            tool required easy assembly
# 56                             bristle set hardwood block
# 64      unit dual fuel technology mean operated using ...
# 65      unit dual fuel technology mean operated using ...
# 66      unit dual fuel technology mean operated using ...
# 67      unit dual fuel technology mean operated using ...
# 70                               oil rubbed bronze finish
# 76                                     steel construction
# 77                                     steel construction
# 78                                     steel construction
# 84               used pouring concrete pad added strength
# 93                                   environment friendly
# ...                                                   ...
# 240677                                         2.80 amp .
# 240681  heavy duty pole high quality safety net ensure...
# 240684  oxygen action even remove colored stain caused...
# 240686                    made eco-friendly hdpe material
# 240687  make long lasting repair wood , plaster , dryw...
# 240688  unmarked , glossy surface finish tapered cap e...
# 240691  foot pedal worked forward reverse direction ta...
# 240695  constructed durable hdpe polywood lumber provi...
# 240696                                                NaN
# 240699  white fitting used sanitary drain , waste , ve...
# 240707                          protected glass ivory mat
# 240709  hand-crafted design exquisite detail top quali...
# 240711                                   assembles second
# 240715                       durable flexible like rubber
# 240718  dual usb port ( 5-volt , 1-amp 5-volt , 2-amp ...
# 240719  item dimension : 63 in. w xbi 24.1 in. xbi 37....
# 240724                 ideal use copper , brass iron pipe
# 240726                          prevents wire rope damage
# 240728                      good cold weather flexibility
# 240731  delivers electricity branch circuit breaker wi...
# 240732                                 steel construction
# 240738      use interior door push pull function required
# 240739  strong construction help withstand weather hum...
# 240740     brillian motion rate 120 superb motion clarity
# 240742                              cover 500 sq.ft. wood
# 240749                                                NaN
# 240753                                 brass construction
# 240754  4-piece modular design simplifies installation...
# 240757                                                NaN
# 240758                                                NaN
#
#                                                  Bullet03  \
# 0          help ensure joint consistently straight strong
# 1          help ensure joint consistently straight strong
# 11      briggs & stratton 7.25 ft. lbs. gross torque 1...
# 12      briggs & stratton 7.25 ft. lbs. gross torque 1...
# 13      briggs & stratton 7.25 ft. lbs. gross torque 1...
# 17                                          easy cut form
# 18                                          easy cut form
# 19                                          easy cut form
# 20                                          easy cut form
# 37                 recycled natural-fiber padding durable
# 47      tubular steel construction durable chrome fini...
# 48      tubular steel construction durable chrome fini...
# 49      tubular steel construction durable chrome fini...
# 50      tubular steel construction durable chrome fini...
# 51      tubular steel construction durable chrome fini...
# 52      tubular steel construction durable chrome fini...
# 53      tubular steel construction durable chrome fini...
# 54      tubular steel construction durable chrome fini...
# 55      tubular steel construction durable chrome fini...
# 56                     use concrete , cement masonry need
# 64      99.9 % energy efficient , vent free design kee...
# 65      99.9 % energy efficient , vent free design kee...
# 66      99.9 % energy efficient , vent free design kee...
# 67      99.9 % energy efficient , vent free design kee...
# 70                                use cabinetry furniture
# 76                                           plain finish
# 77                                           plain finish
# 78                                           plain finish
# 84                                       easier use rebar
# 93                                virtually non-corrosive
# ...                                                   ...
# 240677                     rated 60 c ambient temperature
# 240681  safety net creates fun jumping experience with...
# 240684                                          non-toxic
# 240686  provides look painted wood without maintenance...
# 240687                easy use ready need - add water mix
# 240688          slip-style pipe insertion easy connection
# 240691                    convenient handle add stability
# 240695  polywood lumber requires painting , staining ,...
# 240696                                                NaN
# 240699                              intended pressure use
# 240707         frame washed gold finish gold inner fillet
# 240709  red gold tone light burlap gown blend traditio...
# 240711                  uv treated ensure year beauty use
# 240715                               lightweight like pvc
# 240718  slim design fit easily backpack glove compartment
# 240719                                  finished ash grey
# 240724  wrap plumber 's tape male pipe thread ensure t...
# 240726          feature smooth surface 's ideal wire rope
# 240728                          smooth finish mar surface
# 240731                               trip center position
# 240732                                        zinc-plated
# 240738  fully reversible lever , installed right hande...
# 240739                  compliant nsf 14 61 specification
# 240740            3 hdmi input best picture sound quality
# 240742                                  semi-gloss finish
# 240749                                                NaN
# 240753                                       brass finish
# 240754  continuous hinge swing door allows smooth func...
# 240757                                                NaN
# 240758                                                NaN
#
#                                                  Bullet04  \
# 0                 dimension : 3 in. xbi 3 in. xbi 1-1 2 .
# 1                 dimension : 3 in. xbi 3 in. xbi 1-1 2 .
# 11      personal pace self-propel system sens smoothly...
# 12      personal pace self-propel system sens smoothly...
# 13      personal pace self-propel system sens smoothly...
# 17                                         rust resistant
# 18                                         rust resistant
# 19                                         rust resistant
# 20                                         rust resistant
# 37      blanket-type , foil-faced insulation lightweig...
# 47      perfect storage solution commercial residentia...
# 48      perfect storage solution commercial residentia...
# 49      perfect storage solution commercial residentia...
# 50      perfect storage solution commercial residentia...
# 51      perfect storage solution commercial residentia...
# 52      perfect storage solution commercial residentia...
# 53      perfect storage solution commercial residentia...
# 54      perfect storage solution commercial residentia...
# 55      perfect storage solution commercial residentia...
# 56                                       use variety task
# 64      hand painted log give unit realistic look natu...
# 65      hand painted log give unit realistic look natu...
# 66      hand painted log give unit realistic look natu...
# 67      hand painted log give unit realistic look natu...
# 70                                         screw included
# 76                                        24 in. xbi 12 .
# 77                                        24 in. xbi 12 .
# 78                                        24 in. xbi 12 .
# 84                                     astm a615 material
# 93                                          water soluble
# ...                                                   ...
# 240677                                    1 2 xbi 6 shaft
# 240681            compatible major trampoline frame brand
# 240684                            convenient spray bottle
# 240686  solid , heavy duty construction withstands nat...
# 240687  use indoors outdoors..must kept painted outdoo...
# 240688  work 3 4 in. sch. 40 plumbing grade furniture ...
# 240691  electronic fitness monitor display number stri...
# 240695  solid , heavy duty construction withstands nat...
# 240696                                                NaN
# 240699             maximum working temperature 140 deg. f
# 240707                           includes d-rings hanging
# 240709                          angel measure 18 in. tall
# 240711  step 32 in. wide two ( 2 ) 12-1 2 : deep step ...
# 240715               bend restrictors increased hose life
# 240718                  charged via usb using solar panel
# 240719                              minor assembly needed
# 240724                          working pressure 1000 psi
# 240726              corrosion reducing surface added life
# 240728                       light weight le user fatigue
# 240731                                       120 240-volt
# 240732                                             3 16 .
# 240738                 easily installs minute screwdriver
# 240739             withstands weather become brittle time
# 240740  dts trusurround technology immersive surround ...
# 240742  protects add beauty interior wood surface incl...
# 240749                                                NaN
# 240753                                   # 12 xbi 1-1 2 .
# 240754          reversible door allows hinging left right
# 240757                                                NaN
# 240758                                                NaN
#
#                                                  Bullet05
# 0                                     made 12-gauge steel
# 1                                     made 12-gauge steel
# 11                    3-in-1 : mulch , side discharge bag
# 12                    3-in-1 : mulch , side discharge bag
# 13                    3-in-1 : mulch , side discharge bag
# 17                           36 in. xbi 36 in. xbi 1 50 .
# 18                           36 in. xbi 36 in. xbi 1 50 .
# 19                           36 in. xbi 36 in. xbi 1 50 .
# 20                           36 in. xbi 36 in. xbi 1 50 .
# 37                       excellent acoustical performance
# 47      6 fully adjustable shelf leg help stabilize un...
# 48      6 fully adjustable shelf leg help stabilize un...
# 49      6 fully adjustable shelf leg help stabilize un...
# 50      6 fully adjustable shelf leg help stabilize un...
# 51      6 fully adjustable shelf leg help stabilize un...
# 52      6 fully adjustable shelf leg help stabilize un...
# 53      6 fully adjustable shelf leg help stabilize un...
# 54      6 fully adjustable shelf leg help stabilize un...
# 55      6 fully adjustable shelf leg help stabilize un...
# 56                                                    NaN
# 64      dual burner provides real yellow flame through...
# 65      dual burner provides real yellow flame through...
# 66      dual burner provides real yellow flame through...
# 67      dual burner provides real yellow flame through...
# 70      grayson collection available vintage brass , o...
# 76                                                    NaN
# 77                                                    NaN
# 78                                                    NaN
# 84                                    750 sq.ft. per roll
# 93                                           non-staining
# ...                                                   ...
# 240677      us 10mfd 370 volt. olt capacitor ( included )
# 240681           compatible trampoline leg diameter 1.5 .
# 240684           target neutralizes bad odor smell carpet
# 240686  painting , staining , waterproofing similar ma...
# 240687                  use fill hole wood , plaster tile
# 240688          join xbi solvent welding xbi press-to-fit
# 240691         sturdy steel construction , non-slip pedal
# 240695  polywood lumber splinter , crack , chip , peel...
# 240696                                                NaN
# 240699                                                NaN
# 240707                                                NaN
# 240709                                                NaN
# 240711                                                NaN
# 240715                              300 psi work pressure
# 240718  portable power pack rechargeable battery solar...
# 240719                    cleaned water small brush cloth
# 240724                                                NaN
# 240726                   includes 1-year limited warranty
# 240728             field repairable end fitting save time
# 240731                                         25,000 aic
# 240732                               inward facing flange
# 240738                lifetime mechanical finish warranty
# 240739                                                NaN
# 240740           pc input use pc monitor ( via vga hdmi )
# 240742                                                NaN
# 240749                                                NaN
# 240753                           flat head phillips drive
# 240754  full length magnet ensures secure watertight c...
# 240757                                                NaN
# 240758                                                NaN
#
# [115202 rows x 18 columns]

# %%
df_all.columns
# Out:
# Index(['Unnamed: 0', 'id', 'product_title', 'product_uid', 'relevance',
#        'search_term', 'product_description', 'product_colour', 'brand',
#        'product_weight', 'product_depth', 'product_height', 'product_width',
#        'Bullet01', 'Bullet02', 'Bullet03', 'Bullet04', 'Bullet05'],
#       dtype='object')

# %%
df_try_loaded[df_try_loaded.search_term.isnull()]
# Out:
#             id                                      product_title  \
# 3782     11752  teks # 12 2-3 4 in. phillips flat head self dr...
# 5302     16601  hampton bay adonia 52 in. oil rubbed bronze ce...
# 8832     27425  hampton bay waterton ii 52 in. oil rubbed bron...
# 8999     27953  hampton bay tri mount 52 in. oil rubbed bronze...
# 9105     28230   westek programmable cordless screw light control
# 17860    55100  hampton bay 1 light oil rubbed bronze outdoor ...
# 17946    55372  commercial electric 1 light oil rubbed bronze ...
# 18072    55762  home decorator collection trafton 60 in. oil r...
# 18109    55898  hampton bay 2 light oil rubbed bronze flush mount
# 22214    68566                    everbilt 3 in. tank to-bowl kit
# 22456    69261  nance carpet rug 12 ft. xbi 15 ft. beige unbou...
# 22751    70056  trafficmaster 36 in. tile carpet hardwood tran...
# 24922    76500  philip 60 w equivalent soft white spiral dusk ...
# 26487    81246  glacier bay 3 in. rubber tank to-bowl gasket h...
# 31249    95573  heath zenith shaker cove mission 150 deg. outd...
# 34447   105334  pelican progear 35 qt. orange elite marine cooler
# 35506   108561  defiant automatic dusk to-dawn light control -...
# 37412   114426  hampton bay carrolton ii led 52 in. oil rubbed...
# 39088   119352  brasscraft 3 8 in. fip inlet xbi 3 8 in. o.d. ...
# 51361   155970                     steren dvi female hdmi adapter
# 80784     9913  hampton bay devereaux ii 52 in. oil rubbed bro...
# 88254    20841  leviton 660 watt. lamp holder outlet adapter -...
# 88452    21134  action organic 1-5 gal. pail organic purpose c...
# 97288    34323  yosemite home decor columbia rock 2 light oil ...
# 97738    35036  hampton bay lampkin 52 in. oiled rubbed bronze...
# 105018   45777                  32 in. pre lit rudolph north pole
# 109713   52729          & amp ; trimline telephone memory - black
# 111380   55214  philip 60 w equivalent soft white spiral dusk ...
# 119227   66740  hampton bay 1 light oil rubbed bronze outdoor ...
# 120646   68903  home decorator collection cut to-width 2 in. f...
# 123050   72595  glade winter collection 9.7 oz. peace holiday ...
# 124755   75163  bali cut to-size 1 in. room darkening vinyl mi...
# 125863   76832  brookhurst 52 in. indoor oil rubbed bronze cei...
# 127358   79055  & amp ; corded telephone caller id , call wait...
# 138154   95222  pro twin head outdoor white dusk to-dawn round...
# 141705  100517  safavieh organic multi 7 ft. 6 in. xbi 9 ft. 6...
# 147456  109056             & amp ; corded speaker phone caller id
# 149252  111724  glade winter collection 3.8 oz. peace holiday ...
# 153756  118471  murray 20 amp. double pole type mp combination...
# 157052  123461  lithonia lighting wall post mount outdoor led ...
# 166347  137567  girl power work small s721 tricot lady fitted ...
# 167938  139967  bosmere wall store 6 ft. xbi 2 ft. 8 in. wood ...
# 168780  141242        everbilt brass tank lever rubber oil handle
# 174728  150079  foremost cove 22.5 in. 24.5 in. xbi 72 in. h. ...
# 181374  160015  girl power work 22 in. lady eyewear sport stra...
# 182128  161157  glade winter collection 0.67 oz. peace holiday...
# 197790  185055  & amp ; 4 line speakerphone caller id call wai...
# 221420  221386  girl power work lucy lady eye protection clear...
# 228265  228266  arm & amp ; hammer 122.5 oz. fresh scent liqui...
# 229842  229843      behr marquee # m510-2 life sea exterior paint
# 230161  230162                    & amp ; dect 6.0 cordless phone
# 234440  234441  & amp ; dect 6.0 2 line corded cordless blueto...
# 240706  240707  macally mini display port vga monitor , hdmi h...
# 240717  240718  hampton bay 2 light outdoor oil rubbed bronze ...
#
#         product_uid  relevance search_term  \
# 3782         102051       1.00         NaN
# 5302         102930       1.67         NaN
# 8832         105706       1.00         NaN
# 8999         105854       1.67         NaN
# 9105         105950       2.00         NaN
# 17860        114426       1.67         NaN
# 17946        114511       1.00         NaN
# 18072        114641       1.67         NaN
# 18109        114691       1.33         NaN
# 22214        119080       1.00         NaN
# 22456        119322       1.00         NaN
# 22751        119616       2.33         NaN
# 24922        121988       1.67         NaN
# 26487        123815       1.67         NaN
# 31249        129593       2.33         NaN
# 34447        133788       1.67         NaN
# 35506        135195       1.67         NaN
# 37412        137874       1.67         NaN
# 39088        140211       2.00         NaN
# 51361        159458       1.00         NaN
# 80784        101692        NaN         NaN
# 88254        103853        NaN         NaN
# 88452        103943        NaN         NaN
# 97288        107770        NaN         NaN
# 97738        107982        NaN         NaN
# 105018       111298        NaN         NaN
# 109713       113622        NaN         NaN
# 111380       114465        NaN         NaN
# 119227       118435        NaN         NaN
# 120646       119199        NaN         NaN
# 123050       120566        NaN         NaN
# 124755       121498        NaN         NaN
# 125863       122111        NaN         NaN
# 127358       122950        NaN         NaN
# 138154       129450        NaN         NaN
# 141705       131688        NaN         NaN
# 147456       135420        NaN         NaN
# 149252       136643        NaN         NaN
# 153756       139793        NaN         NaN
# 157052       142202        NaN         NaN
# 166347       149305        NaN         NaN
# 167938       150574        NaN         NaN
# 168780       151255        NaN         NaN
# 174728       156078        NaN         NaN
# 181374       161825        NaN         NaN
# 182128       162511        NaN         NaN
# 197790       178048        NaN         NaN
# 221420       206577        NaN         NaN
# 228265       212562        NaN         NaN
# 229842       213997        NaN         NaN
# 230161       214289        NaN         NaN
# 234440       218269        NaN         NaN
# 240706       224375        NaN         NaN
# 240717       224386        NaN         NaN
#
#                                       product_description  \
# 3782    teks # 12 xbi 2-3 4 in. fine zinc plated steel...
# 5302    great transitional accent room , hampton bay a...
# 8832    hampton bay waterton 52 in. ceiling fan oil ru...
# 8999    hampton bay tri mount oil rubbed bronze energy...
# 9105    screw light control us photocell technology tu...
# 17860   use hampton bay wall mount 1 light oil rubbed ...
# 17946   featured 4 pack oil rubbed bronze 1 light flus...
# 18072   hampton bay trafton 60 in. oil rubbed bronze c...
# 18109   add classic style den , living room interior s...
# 22214   help prevent leak occurring toilet tank bowl t...
# 22456   pay full price carpet buy carpet remnant half ...
# 22751   t36 in. tile carpet hardwood transition connec...
# 24922   philip energy saver compact fluorescent 60 wat...
# 26487   glacier bay 3 in. rubber tank to-bowl gasket h...
# 31249   shaker cove mission 150 deg. motion sensing ou...
# 34447   pelican progear 35 qt. orange elite marine coo...
# 35506   indoor outdoor light , use automatic dusk to-d...
# 37412   carrolton 52 in. oil rubbed bronze ceiling fan...
# 39088   brasscraft 3 8 in. fip inlet xbi 3 8 in. o.d. ...
# 51361   steren 's hdmi dvi adapter dvi plug adapter on...
# 80784   hampton bay devereaux ii oil rubbed bronze cei...
# 88254   leviton offer variety electrical accessory res...
# 88452   mc-10-7 5 gal. pail organic purpose cleaner de...
# 97288   columbia rock collection xbi yosemite home dec...
# 97738   lampkin 52 in. ceiling fan come rich oil rubbe...
# 105018  easy to-position flat back design , 2 pre lit ...
# 109713  popular affordable telephone , 210 designed n'...
# 111380  philip energy saver compact fluorescent 14 wat...
# 119227  featuring oil rubbed bronze finish clear bevel...
# 120646  design meet functionality white 2 in. faux woo...
# 123050  eliminate odor freshen air. glade room spray f...
# 124755  bali cut to-size vinyl blind durable functiona...
# 125863  add traditional touch home 's decor hampton ba...
# 127358  cl2909 speakerphone caller id call waiting use...
# 138154  new pro dusk to-dawn led twin head round flood...
# 141705  fashion meet sustainability safavieh 's new or...
# 147456  communicate ease corded speakerphone large dis...
# 149252  glade holiday candle quickly fill room fragran...
# 153756  siemens 20 amp. 3-1 2 in. double pole combinat...
# 157052  wall post mount outdoor grey led area light li...
# 166347  erb safety 's girl power work vest specificall...
# 167938  wall store storage shed ideal outdoor storage ...
# 168780  universal toilet tank lever fit front mounted ...
# 174728  whether designing new bathroom , renovating cu...
# 181374  erb safety 's girl power work sport strap grea...
# 182128  glade plug scented oil brings true to-life fra...
# 197790  four line corded business system phone feature...
# 221420  lucy eyewear made specifically lady work. eyew...
# 228265  arm & hammer 125 oz. fresh scent liquid laundr...
# 229842  ultimate durability beauty virtually exterior ...
# 230161  modern fully featured , & cl82401 system come ...
# 234440  stop missing cellular phone call home & dect 6...
# 240706  great product hook macbook tv , projector moni...
# 240717  hampton bay 2 light oil rubbed bronze outdoor ...
#
#                  product_colour product_weight                      brand  \
# 3782                        NaN            .02                       teks
# 5302               bronze brown     18.48 lb .                hampton bay
# 8832               bronze brown          24.93                hampton bay
# 8999               bronze brown          16.48                hampton bay
# 9105                        NaN           0.11                     westek
# 17860         rubbed bronze oil      1.39 lb .                hampton bay
# 17946                       NaN            NaN                        NaN
# 18072              bronze brown          27.87  home decorator collection
# 18109   bronze oil rubbed white           3.59                hampton bay
# 22214                       NaN            NaN                        NaN
# 22456               cream beige            NaN           nance carpet rug
# 22751                grain wood            NaN              trafficmaster
# 24922        2700 soft white 82            NaN                     philip
# 26487                       NaN            NaN                glacier bay
# 31249       bronze oiled rubbed      2.75 lb .               heath zenith
# 34447                       NaN            NaN                        NaN
# 35506                       NaN            .06                    defiant
# 37412              bronze brown          16.79                hampton bay
# 39088                       NaN            NaN                        NaN
# 51361                       NaN            NaN                        NaN
# 80784      bronze black , brown             24                hampton bay
# 88254                     white           0.05                    leviton
# 88452                       NaN            NaN             action organic
# 97288   bronze oil rubbed white           6.12        yosemite home decor
# 97738              bronze brown             19                hampton bay
# 105018                      NaN            NaN                  unbranded
# 109713                      NaN            NaN                        NaN
# 111380       2700 soft white 82            NaN                     philip
# 119227        bronze oil rubbed      1.84 lb .                hampton bay
# 120646                    white           9.37  home decorator collection
# 123050                      NaN            NaN                      glade
# 124755                    white              8           bali cut-to-size
# 125863    bronze maple , walnut          16.74                  unbranded
# 127358                      NaN            NaN                        NaN
# 138154   5000 daylight 70 white            2.5                    all-pro
# 141705                      NaN            NaN                        NaN
# 147456                      NaN            NaN                          &
# 149252                      NaN            NaN                      glade
# 153756                      NaN           0.72                     murray
# 157052                     grey            3.5          lithonia lighting
# 166347                 red pink           .347            girl power work
# 167938                brown tan            172                    bosmere
# 168780                      NaN            NaN                        NaN
# 174728                      NaN             43                   foremost
# 181374                      NaN            NaN                        NaN
# 182128                      NaN            NaN                        NaN
# 197790                      NaN            NaN                          &
# 221420                      NaN           .118            girl power work
# 228265                      NaN            NaN               arm & hammer
# 229842            life sea blue            NaN               behr marquee
# 230161                      NaN            NaN                          &
# 234440                      NaN            NaN                          &
# 240706                    white            NaN                    macally
# 240717        bronze oil rubbed      2.99 lb .                hampton bay
#
#        product_depth product_height product_width  \
# 3782             NaN            NaN           NaN
# 5302             NaN            NaN           NaN
# 8832             NaN            NaN           NaN
# 8999             NaN            NaN           NaN
# 9105             1.6              3           1.6
# 17860              6            8 .        4.63 .
# 17946            NaN            NaN           NaN
# 18072            NaN            NaN           NaN
# 18109             13           6.75            13
# 22214            NaN            NaN           NaN
# 22456            NaN            NaN           144
# 22751            NaN            NaN           1.5
# 24922           5.28            7.4          2.56
# 26487            4.5           1.25           4.5
# 31249           6.75       11.125 .         4.5 .
# 34447            NaN            NaN           NaN
# 35506           1.75              2           1.5
# 37412            NaN            NaN           NaN
# 39088            NaN            NaN           NaN
# 51361            NaN            NaN           NaN
# 80784            NaN            NaN           NaN
# 88254           1.13              1          1.13
# 88452            NaN            NaN           NaN
# 97288           6.63           9.38            15
# 97738            NaN            NaN           NaN
# 105018            18             32             6
# 109713           NaN            NaN           NaN
# 111380          5.28            7.4          2.56
# 119227          7.75         14.5 .           6.5
# 120646             2             64            35
# 123050           NaN            NaN           NaN
# 124755           1.5             48            72
# 125863           NaN            NaN           NaN
# 127358           NaN            NaN           NaN
# 138154           6.6            5.5           7.2
# 141705           NaN            NaN           NaN
# 147456          10.3            3.4           9.3
# 149252          3.25           3.25         3.063
# 153756             3            6.5           6.5
# 157052        11.375          9.125           9.5
# 166347           NaN            NaN           NaN
# 167938            32             65            72
# 168780           NaN            NaN           NaN
# 174728           1.5             72          24.5
# 181374           NaN            NaN           NaN
# 182128           NaN            NaN           NaN
# 197790         11.75           4.75          9.75
# 221420          1.75          10.25           4.5
# 228265           NaN            NaN           NaN
# 229842           NaN            NaN           NaN
# 230161           9.7            5.5             7
# 234440           9.9            4.4           8.9
# 240706           3.3           1.73          0.54
# 240717         12.75          5.5 .       12.75 .
#
#                                                  Bullet01  \
# 3782                                use fasten wood metal
# 5302    5 reversible walnut dark maple present choice ...
# 8832    5-reversible medium maple cherry blade allows ...
# 8999    five reversible blade walnut finish one side s...
# 9105                   determines optimal time turn light
# 17860                            oil rubbed bronze finish
# 17946                                                 NaN
# 18072           five reversible medium maple cherry blade
# 18109                            oil rubbed bronze finish
# 22214                                                 NaN
# 22456                      textured plush carpet material
# 22751   natural wood withstands high foot traffic area...
# 24922                              brightness : 770 lumen
# 26487                        high-quality rubber material
# 31249   metal housing oil-rubbed bronze weather-resist...
# 34447                                                 NaN
# 35506                   turn incandescent light dusk dawn
# 37412   five reversible dark maple cherry blade allows...
# 39088                                                 NaN
# 51361                                                 NaN
# 80784             reversible blade let change look easily
# 88254                                        white finish
# 88452     water based mixture anionic cationic ingredient
# 97288   oil rubbed bronze frame white etched opal glas...
# 97738           five reversible walnut medium maple blade
# 105018  heavy-duty metal frame construction ensures la...
# 109713                                                NaN
# 111380                             brightness : 770 lumen
# 119227  cast aluminum construction weather resistant o...
# 120646                              35 in. w xbi 64 in. l
# 123050  fragrance specially designed create atmosphere...
# 124755                              72 in. w xbi 48 in. l
# 125863  five reversible walnut maple blade make easy c...
# 127358                                                NaN
# 138154    integral photocell provides dusk dawn operation
# 141705                                                NaN
# 147456                                       corded phone
# 149252                                  redesigned candle
# 153756  use combination circuit breaker afci device de...
# 157052                                 produce 3150 lumen
# 166347                             100 % polyester tricot
# 167938  great storing bike , outdoor toy , pool equipm...
# 168780                                                NaN
# 174728  constructed 1 4 in. tempered safety glass extr...
# 181374                                                NaN
# 182128                                                NaN
# 197790              page , intercom call transfer station
# 221420           meet requirement ansi z87.1 impact rated
# 228265  multi-enzyme formula penetrates deep eliminate...
# 229842  protection wood , vinyl , aluminum , fiber cem...
# 230161                                dect 6.0 technology
# 234440                                dect 6.0 technology
# 240706  designed apple computer thunderbolt port mini ...
# 240717  steel aluminum construction oil-rubbed bronze ...
#
#                                                  Bullet02  \
# 3782                          ideal use metal thick gauge
# 5302            bowl-style light kit aged champagne glass
# 8832                             oil rubbed bronze finish
# 8999                             oil rubbed bronze finish
# 9105              retains programmed setting power outage
# 17860                                 frosted white shade
# 17946                                                 NaN
# 18072   attractive oil rubbed bronze finish transition...
# 18109   us 2-medium-base bulb ( 75 watt. maximum ) ( s...
# 22214                                                 NaN
# 22456          carpet pad recommended ( sold separately )
# 22751   use doorway , room entry way location tile car...
# 24922   estimated yearly energy cost : $ 1.93 ( based ...
# 26487   rubber construction durable , flexible lightwe...
# 31249                                  seeded glass panel
# 34447                                                 NaN
# 35506   use indoor translucent lamp shade outdoor rain...
# 37412                            oil rubbed bronze finish
# 39088                                                 NaN
# 51361                                                 NaN
# 80784                            oil rubbed bronze finish
# 88254               medium base lampholder outlet adapter
# 88452                         mixture surfactant alkaline
# 97288        sturdily built last steel glass construction
# 97738                         oiled bronzed custom finish
# 105018      70 light illuminate scene create festive glow
# 109713                                                NaN
# 111380  estimated yearly energy cost : $ 1.93 ( based ...
# 119227                         clear , curved panel glass
# 120646                           fit window : 35 in. wide
# 123050  glade holiday collection feature fragrance cap...
# 124755                          actual blind width 71.5 .
# 125863  oil-rubbed bronze finish complement wide varie...
# 127358                                                NaN
# 138154                                         1600 lumen
# 141705                                                NaN
# 147456                                         big button
# 149252                     fragrance lingers candle blown
# 153756  detects 3 type arc fault help reduce risk elec...
# 157052                                  energy star rated
# 166347                      side slit give ease along hip
# 167938                               lockable double door
# 168780                                                NaN
# 174728  modern 1 4 in. frameless pivot door complement...
# 181374                                                NaN
# 182128                                                NaN
# 197790                                1 4 line capability
# 221420                      comfortable ultra lightweight
# 228265  oxiclean baking soda clean 101 stain keep whit...
# 229842                            low voc , 100 % acrylic
# 230161                                  talking caller id
# 234440                             bluetooth connectivity
# 240706  support dvi , hdmi vga , 3 convenient output o...
# 240717                   frosted glass help diffuse light
#
#                                                  Bullet03  \
# 3782                                     screw tap thread
# 5302        3-speed reversible control year-round comfort
# 8832           3-light kit frosted drum style glass globe
# 8999    1-bulb integrated frosted opal schoolhouse lig...
# 9105                  random feature discourages intruder
# 17860              includes 1-13-watt cfl gu24-light bulb
# 17946                                                 NaN
# 18072                        bowl light kit frosted glass
# 18109   durable steel construction painted finish give...
# 22214                                                 NaN
# 22456                                            made usa
# 22751   snap track firmly hold hardwood transition pla...
# 24922                  life : 7.3 year ( based 3 hr day )
# 26487                       advanced design excellent fit
# 31249                             wall-mount installation
# 34447                                                 NaN
# 35506         compact design fit enclosed outdoor fixture
# 37412                  bowl style light kit frosted glass
# 39088                                                 NaN
# 51361                                                 NaN
# 80784               integrated dome light kit amber glass
# 88254             nema 1-15r outlet , non-grounded outlet
# 88452        introducing hazard free chemical formulation
# 97288          design installs easily wall light bathroom
# 97738   frosted opal light kit three energy efficient ...
# 105018                   flat back design fit easily wall
# 109713                                                NaN
# 111380                 life : 7.3 year ( based 3 hr day )
# 119227            us 1-bulb maximum 100-watt ( included )
# 120646                          actual blind width 34.5 .
# 123050                                         soft spray
# 124755  note : blind 0.5 in. ( 1.27 cm. ) narrower ord...
# 125863                3-light kit light amber glass shade
# 127358                                                NaN
# 138154                                              5000k
# 141705                                                NaN
# 147456                                 large tilt display
# 149252                                         burn 30 hr
# 153756                                 led trip indicator
# 157052  100,000-hour life integrated led ( 4000k ) mea...
# 166347                       a-line cut tailored shoulder
# 167938  built 1 2 in. shiplap cladding dipped honey br...
# 168780                                                NaN
# 174728  1 4 in. tempered safety glass protected xbi cl...
# 181374                                                NaN
# 182128                                                NaN
# 197790                         200-name number phone book
# 221420                                   frameless design
# 228265  high performance detergent used machine including
# 229842                        exceptional gloss retention
# 230161       push talk instant easy communication headset
# 234440                                      2 line system
# 240706                            auto detect plug-n-play
# 240717  transitional style help maintain consistent decor
#
#                                                  Bullet04  \
# 3782                          steel construction strength
# 5302    flush-mount , 'hugger-style ' fan ideal low ce...
# 8832                             remote control adaptable
# 8999                                         wall control
# 9105                  turn light dusk , 2 , 5 , 8 hr dawn
# 17860                               energy star qualified
# 17946                                                 NaN
# 18072                                        wall control
# 18109                                           ul listed
# 22214                                                 NaN
# 22456   wrapped heavy-duty plastic protect product thr...
# 22751                         cut desired length hand saw
# 24922             light appearance : 2700k ( soft white )
# 26487   inner-ridge contour deliver snug fit tank bowl...
# 31249          150-degree , 30 ft. field motion detection
# 34447                                                 NaN
# 35506      copper prevents corrosion occurs aluminum bulb
# 37412                                        wall control
# 39088                                                 NaN
# 51361                                                 NaN
# 80784   handheld remote control light speed operation ...
# 88254             15 amp. , 660 watt. , 125 volt. 2p , 2w
# 88452          action organic 100 % organic biodegradable
# 97288            transitional design fit almost structure
# 97738   three speed manual reverse summer winter opera...
# 105018  perfect size versatile decorating : look great...
# 109713                                                NaN
# 111380            light appearance : 2700k ( soft white )
# 119227  photocell automatically illuminates fixture du...
# 120646  pre-cut xbi 1 2 in. accommodate mounting brack...
# 123050  specially formulated fight even toughest cooki...
# 124755            inside mount , fit window : 72 in. wide
# 125863                                       wall control
# 127358                                                NaN
# 138154                             die-cast metal housing
# 141705                                                NaN
# 147456                                       speakerphone
# 149252  consistent fragrance experience beginning end ...
# 153756                                      plug-in style
# 157052  rugged cast aluminum corrosion-resented housin...
# 166347                      great woman work benefit walk
# 167938  weatherproof mineral felt roof pressure treate...
# 168780                                                NaN
# 174728  cove door covered wamm ( sm ) : make mistake p...
# 181374                                                NaN
# 182128                                                NaN
# 197790        32 speed dial 16 in. tercom number location
# 221420                                   anti-fog coating
# 228265  detergent contains bio-gradable surfactant , p...
# 229842                  durable , mildew resistant finish
# 230161                                 hd audio equalizer
# 234440                              expandable 12 handset
# 240706  max resolution 1920 xbi 1080p 60hz , 225mhz 2....
# 240717  flush-mount design mounted indoors outdoors ve...
#
#                                                  Bullet05
# 3782                                       2-3 4 in. long
# 5302                   versatile oil-rubbed bronze finish
# 8832    high performance motor assures powerful , whis...
# 8999    multi-capacitor quiet operation maximum air mo...
# 9105                                                  NaN
# 17860                                                 NaN
# 17946                                                 NaN
# 18072    motor three-speed reversible control versatility
# 18109                                                 NaN
# 22214                                                 NaN
# 22456                         24 oz. - 35 oz. face weight
# 22751                                                 NaN
# 24922   energy used : 14-watt ( equivalent 60-watt sta...
# 26487   use glacier bay het toilet # 331-725 ( toilet ...
# 31249   us one 60-watt maximum medium-base bulb ( incl...
# 34447                                                 NaN
# 35506   activated allow 15 min. unit cycle prevent fli...
# 37412                         motor make 4504 cfm airflow
# 39088                                                 NaN
# 51361                                                 NaN
# 80784   powerful 172 mm. xbi 14 mm. motor superior air...
# 88254                                                 NaN
# 88452                                                 NaN
# 97288                     also available 3 4 light option
# 97738                         heavy duty 153x15 mm. motor
# 105018       includes ground stake spare bulb convenience
# 109713                                                NaN
# 111380  energy used : 14-watt ( equivalent 60-watt sta...
# 119227                                                NaN
# 120646                       ship within 2-3 business day
# 123050                                                NaN
# 124755  outside mount , order 0.5 in. wider overall ar...
# 125863  174 rpm motor multi-capacitor speed control of...
# 127358                                                NaN
# 138154                                    5 year warranty
# 141705                                                NaN
# 147456                                                NaN
# 149252                                                NaN
# 153756                                       120 240-volt
# 157052         polycarbonate lens protects integrated led
# 166347                          available lady size s- 3x
# 167938  external dimension : 5 ft. 4 in. h xbi 6 ft. w...
# 168780                                                NaN
# 174728                                                NaN
# 181374                                                NaN
# 182128                                                NaN
# 197790                        3rd party call conferencing
# 221420                        available white pink temple
# 228265          detergent rinse clean leaf residue behind
# 229842  exceptional hide , cover 2,000 sq.ft. dependin...
# 230161                       call transfer using intercom
# 234440                             pair 4 bluetooth phone
# 240706  powered xbi apple computer ( ac adapter requir...
# 240717                       weather resistant durability

# %%
from difflib import SequenceMatcher
import Levenshtein
import distance

def sequence_match_score(s1,s2):
    #Ratcliff-Obershelp algorithm score
    seq=SequenceMatcher(None,s1,s2)
    
    return seq.ratio()

def levenshtein_dist(s1,s2):
    #normalized Levenshtein distance
    
    return Levenshtein.ratio(s1,s2)

def Jaccard_dist(s1,s2):
    #normalized Jaccardian distance
    set1, set2= set(s1.split()),set(s2.split())
    
    return float(len(set1 & set2)) / len(set1 | set2)

def full_string_match_count(s1, s2):
    
    #count the number of times s1 appears in s2
    count = 0
    index = 0
    if s1=='':
        return 0
    while index < len(s2):
        index = s2.find(s1, index)
        if index == -1:
            #no match
            return count
        else:
            count += 1
            index += len(s1)
    return count

def common_words_match_count(s1, s2):
    
    #count the number of common words between s1 and s2
    return sum([int(s2.find(word)>=0) for word in s1.split()])

test_string=['hello world','hello world hello. My name is hello world']

print(full_string_match_count('',test_string[1]))

print(common_words_match_count(test_string[0],test_string[1]))
# Out:
# 0
# 2

# %%
df_all['num_words_query'] = df_all['search_term'].map(lambda x:len(x.split()) )
df_all['num_words_title'] = df_all['product_title'].map(lambda x:len(x.split()))
df_all['num_words_brand'] = df_all['brand'].map(lambda x:len(x.split()) if type(x)==str else 1)
df_all['num_words_colour'] = df_all['product_colour'].map(lambda x:len(x.split()) if type(x)==str else 1)
df_all['num_words_weight'] = df_all['product_weight'].map(lambda x:len(x.split()) if type(x)==str else 1)
df_all['num_words_height'] = df_all['product_height'].map(lambda x:len(x.split()) if type(x)==str else 1)
df_all['num_words_depth'] = df_all['product_depth'].map(lambda x:len(x.split()) if type(x)==str else 1 )
df_all['num_words_width'] = df_all['product_width'].map(lambda x:len(x.split()) if type(x)==str else 1 )



#SEARCH TERM AND PRODUCT TITLE SECTION
a=timeit.default_timer()

df_query_and_title=df_all['search_term'] + '||' + df_all['product_title']

df_all['query_in_title']=df_query_and_title.map(lambda x: full_string_match_count(x.split('||')[0],
                                                                                  x.split('||')[1]))
df_all['common_words_query_and_title']=df_query_and_title.map(lambda x: common_words_match_count(x.split('||')[0],
                                                                                                 x.split('||')[1]))
df_all['query_last_word_in_title'] = df_query_and_title.map(lambda x:common_words_match_count(x.split('||')[0].split(" ")[-1],
                                                                                              x.split('||')[1]))

df_all['title_seq_match_score']=df_query_and_title.map(lambda x: sequence_match_score(x.split('||')[0],
                                                                                      x.split('||')[1]))

df_all['title_levenshtein_ratio']=df_query_and_title.map(lambda x: levenshtein_dist(x.split('||')[0],
                                                                                    x.split('||')[1]))

df_all['title_Jaccard_dist_norm']=df_query_and_title.map(lambda x: Jaccard_dist(x.split('||')[0],
                                                                                x.split('||')[1]))
df_all['ratio_title'] = df_all['common_words_query_and_title']/df_all['num_words_query']

del df_query_and_title
b=timeit.default_timer()

print('product title feature engineering took {}s'.format(b-a))

#SEARCH TERM AND DESCRIPTION
a=timeit.default_timer()

df_query_and_desc = df_all['search_term'] + '||' + df_all['product_description']
df_all['query_in_description'] = df_query_and_desc.map(lambda x: full_string_match_count(x.split('||')[0],
                                                                                         x.split('||')[1]))

df_all['common_words_query_and_desc']= df_query_and_desc.map(lambda x: common_words_match_count(
    x.split('||')[0],x.split('||')[1]))
df_all['query_last_word_in_desc'] = df_query_and_desc.map(lambda x:common_words_match_count(x.split('||')[0].split(" ")[-1],
                                                                                            x.split('||')[1]))

df_all['desc_sequence_match_score'] = df_query_and_desc.map(lambda x: sequence_match_score(x.split('||')[0],
                                                                                      x.split('||')[1]))
df_all['desc_levenshtein_ratio'] = df_query_and_desc.map(lambda x: levenshtein_dist(x.split('||')[0],
                                                                                x.split('||')[1]))
df_all['desc_Jaccard_dist_norm'] = df_query_and_desc.map(lambda x: Jaccard_dist(x.split('||')[0],
                                                                                x.split('||')[1]))

df_all['ratio_description'] = df_all['common_words_query_and_desc'] / df_all['num_words_query']

del df_query_and_desc 
b=timeit.default_timer()

print('product desc feature engineering took {}s'.format(b-a))

#SEARCH TERM AND BRAND
a=timeit.default_timer()

df_query_and_brand = df_all['search_term'] + '||' + df_all['brand']
df_query_and_brand.dropna(inplace=True)
df_all['query_in_brand'] = df_query_and_brand.map(lambda x: full_string_match_count(x.split('||')[0],
                                                                                    x.split('||')[1]))

df_all['common_words_query_and_brand']= df_query_and_brand.map(lambda x: common_words_match_count(x.split('||')[0],
    x.split('||')[1]))
#last word in brand doesn't make sense

df_all['brand_sequence_match_score'] = df_query_and_brand.map(lambda x: sequence_match_score(x.split('||')[0],
                                                                                      x.split('||')[1]))
df_all['brand_levenshtein_ratio'] = df_query_and_brand.map(lambda x: levenshtein_dist(x.split('||')[0],
                                                                                x.split('||')[1]))
df_all['brand_Jaccard_dist_norm'] = df_query_and_brand.map(lambda x: Jaccard_dist(x.split('||')[0],
                                                                                x.split('||')[1]))

df_all['ratio_brand'] = df_all['common_words_query_and_brand'] / df_all['num_words_query']

del df_query_and_brand
b=timeit.default_timer()

print('brand feature engineering took {}s'.format(b-a))

#SEARCH TERM AND COLOUR

a=timeit.default_timer()

df_query_and_colour = df_all['search_term']+'||'+df_all['product_colour']
df_query_and_colour.dropna(inplace=True) #dropna cause brands do not exist for every product uid and hence a search term
df_all['query_in_colour'] = df_query_and_colour.map(lambda x: full_string_match_count(x.split('||')[0],
                                                                                    x.split('||')[1]))

df_all['common_words_query_and_colour']= df_query_and_colour.map(lambda x: common_words_match_count(x.split('||')[0],
    x.split('||')[1]))
#last word in colour doesn't make sense
df_all['query_first_word_in_colour'] = df_query_and_colour.map(lambda x:common_words_match_count(x.split('||')[0].split(" ")[0],
                                                                                            x.split('||')[1]))

df_all['colour_sequence_match_score'] = df_query_and_colour.map(lambda x: sequence_match_score(x.split('||')[0],
                                                                                      x.split('||')[1]))
df_all['colour_levenshtein_ratio'] = df_query_and_colour.map(lambda x: levenshtein_dist(x.split('||')[0],
                                                                                x.split('||')[1]))
df_all['colour_Jaccard_dist_norm'] = df_query_and_colour.map(lambda x: Jaccard_dist(x.split('||')[0],
                                                                                x.split('||')[1]))

df_all['ratio_colour'] = df_all['common_words_query_and_colour'] / df_all['num_words_query']

del df_query_and_colour


b=timeit.default_timer()

print('colour feature engineering took {}s'.format(b-a))


#SEARCH TERM AND SIZE 

a=timeit.default_timer()
df_query_and_size = df_all['search_term'] + '||' + df_all['product_weight'] + ' ' +\
df_all['product_height'] + ' ' + df_all['product_depth'] + ' ' + df_all['product_width']

df_query_and_size.dropna(inplace=True) 

#query in size doesn't make sense
df_all['common_words_query_and_size']= df_query_and_size.map(lambda x: common_words_match_count(x.split('||')[0],
    x.split('||')[1]))

#first word in size doesn't make sense
df_all['query_last_word_in_size'] = df_query_and_size.map(lambda x:common_words_match_count(x.split('||')[0].split(" ")[-1],
                                                                                            x.split('||')[1]))

df_all['size_sequence_match_score'] = df_query_and_size.map(lambda x: sequence_match_score(x.split('||')[0],
                                                                                      x.split('||')[1]))
df_all['size_levenshtein_ratio'] = df_query_and_size.map(lambda x: levenshtein_dist(x.split('||')[0],
                                                                                x.split('||')[1]))
df_all['size_Jaccard_dist_norm'] = df_query_and_size.map(lambda x: Jaccard_dist(x.split('||')[0],
                                                                                x.split('||')[1]))

df_all['ratio_size'] = df_all['common_words_query_and_size'] / df_all['num_words_query']

del df_query_and_size

b=timeit.default_timer()

print('size feature engineering took {}s'.format(b-a))

#SEARCH TERM AND BULLETPOINTS
a=timeit.default_timer()

df_query_and_bullets = df_all['search_term'] + '||'  + df_all['Bullet01'] + df_all['Bullet02'] + ' ' +\
df_all['Bullet03'] + ' ' + df_all['Bullet04'] + ' ' + df_all['Bullet05']

df_query_and_bullets.dropna(inplace=True) 

df_all['query_in_bullets'] = df_query_and_bullets.map(lambda x: full_string_match_count(x.split('||')[0],
                                                                                    x.split('||')[1]))

df_all['common_words_query_and_bullets']= df_query_and_bullets.map(lambda x: common_words_match_count(x.split('||')[0],
    x.split('||')[1]))

#last word in bulletpoints doesn't make sense
df_all['bullets_sequence_match_score'] = df_query_and_bullets.map(lambda x: sequence_match_score(x.split('||')[0],
                                                                                      x.split('||')[1]))
df_all['bullets_levenshtein_ratio'] = df_query_and_bullets.map(lambda x: levenshtein_dist(x.split('||')[0],
                                                                                x.split('||')[1]))
df_all['bullets_Jaccard_dist_norm'] = df_query_and_bullets.map(lambda x: Jaccard_dist(x.split('||')[0],
                                                                                x.split('||')[1]))

df_all['ratio_bullets'] = df_all['common_words_query_and_bullets'] / df_all['num_words_query']

del df_query_and_bullets

b=timeit.default_timer()

print('bulletpoints feature engineering took {}s'.format(b-a))
# Out:
# product title feature engineering took 27.861316385038663s
# product desc feature engineering took 75.16362875897903s
# brand feature engineering took 11.526185650960542s
# colour feature engineering took 9.043073154985905s
# size feature engineering took 5.3187357889837585s
# bulletpoints feature engineering took 26.73640765598975s

# %%
df_all.drop('Unnamed: 0',axis=1,inplace=True)
df_all
# Out:
#             id                                      product_title  \
# 0            2                  simpson strong tie 12 gauge angle
# 1            3                  simpson strong tie 12 gauge angle
# 2            9  behr premium textured deckover 1 gal. # sc-141...
# 3           16  delta vero 1 handle shower faucet trim kit chr...
# 4           17  delta vero 1 handle shower faucet trim kit chr...
# 5           18  whirlpool 1.9 cu.ft. range convection microwav...
# 6           20  whirlpool 1.9 cu.ft. range convection microwav...
# 7           21  whirlpool 1.9 cu.ft. range convection microwav...
# 8           23  lithonia lighting quantum 2 light black led em...
# 9           27  house fara 3 4 in. xbi 3 in. xbi 8 ft. mdf flu...
# 10          34        valley view industry metal stake ( 4 pack )
# 11          35  toro personal pace recycler 22 in. variable sp...
# 12          37  toro personal pace recycler 22 in. variable sp...
# 13          38  toro personal pace recycler 22 in. variable sp...
# 14          48  hampton bay caramel simple weave bamboo rollup...
# 15          51  insinkerator sinktop switch single outlet insi...
# 16          65  sunjoy calais 8 ft. xbi 5 ft. xbi 8 ft. steel ...
# 17          69  md building product 36 in. xbi 36 in. cloverle...
# 18          75  md building product 36 in. xbi 36 in. cloverle...
# 19          81  md building product 36 in. xbi 36 in. cloverle...
# 20          85  md building product 36 in. xbi 36 in. cloverle...
# 21          88  house fara 8 linear ft. mdf overlapping wainsc...
# 22          90  house fara 8 linear ft. mdf overlapping wainsc...
# 23          92  house fara 8 linear ft. mdf overlapping wainsc...
# 24         101  house fara 8 linear ft. mdf overlapping wainsc...
# 25         105  house fara 8 linear ft. mdf overlapping wainsc...
# 26         106  house fara 8 linear ft. mdf overlapping wainsc...
# 27         113  1804 dual spray half pattern 4 in. pop spray head
# 28         114  1804 dual spray half pattern 4 in. pop spray head
# 29         117  samsung 4.2 cu.ft. front load washer steam whi...
# ...        ...                                                ...
# 240730  240731                      6 panel composite bifold door
# 240731  240732    eaton csr 200 amp. double pole main breaker kit
# 240732  240733  crown bolt 3 16 in. zinc plated steel axle hat...
# 240733  240734                dicky 2 pocket utility knife sheath
# 240734  240735  patio living concept san juan 60 in. outdoor b...
# 240735  240736             speakman emergency eyewash safety sign
# 240736  240737              plantronics cable m12 cs50 cs55 phone
# 240737  240738  glomar vanguard 9 light textured black chandel...
# 240738  240739        kwikset milan satin nickel half dummy lever
# 240739  240740  advanced drainage system 1 2 in. xbi 100 ft. i...
# 240740  240741  magnavox 50 in. class led 1080 p 120 bmr slim ...
# 240741  240742  ekena millwork 7 in. xbi 3 4 in. xbi 11 in. hi...
# 240742  240743  minwax 1 gal. semi gloss polycrylic protective...
# 240743  240744  southern living plant collection 3 gal. pink s...
# 240744  240745   ge 5.0 cu.ft. gas range self cleaning oven black
# 240745  240746  southwire 150 ft. 12-3 cu w g submersible pump...
# 240746  240747  generac protector series 15000 watt. 120 240 v...
# 240747  240748  kohler clearflo brass toe tap bath drain vibra...
# 240748  240749  casablanca 4 light maiden bronze ceiling fan f...
# 240749  240750  glidden premium 5 gal. # hdgr19 fresh peony sa...
# 240750  240751  everbilt 1 8 in. xbi 50 ft. reflective black p...
# 240751  240752  crown bolt 5 16 in. ( 1 4 in. -20 ) xbi 1-1 2 ...
# 240752  240753  universal tub 4.5 ft. right drain wheel chair ...
# 240753  240754  everbilt # 12 xbi 1-1 2 in. phillips brass fla...
# 240754  240755  coastal shower door legend series 24 in. xbi 6...
# 240755  240756  stufurhome norma 24 in. w xbi 16 in. xbi 34 in...
# 240756  240757  home decorator collection 49 in. alessandro sp...
# 240757  240758  simpson strong tie hb 3-1 2 xbi 14 in. top fla...
# 240758  240759  1 4 in. -20 tpi xbi 1-1 2 in. stainless steel ...
# 240759  240760                      bosch 4 in. bi metal hole saw
#
#         product_uid  relevance                      search_term  \
# 0            100001       3.00                    angle bracket
# 1            100001       2.50                        l bracket
# 2            100002       3.00                             deck
# 3            100005       2.33                 rain shower head
# 4            100005       2.67                    shower faucet
# 5            100006       3.00                   convection otr
# 6            100006       2.67                  microwave stove
# 7            100006       3.00                        microwave
# 8            100007       2.67                  emergency light
# 9            100009       3.00                          mdf 3 4
# 10           100010       2.67                      steel stake
# 11           100011       3.00       briggs stratton lawn mower
# 12           100011       3.00                        gas mower
# 13           100011       2.00                      honda mower
# 14           100012       2.67  hampton bay chestnut pull shade
# 15           100013       2.67                         disposer
# 16           100016       3.00                     grill gazebo
# 17           100017       1.00                       door guard
# 18           100017       1.67           metal plate cover gfci
# 19           100017       2.33                   radiator grate
# 20           100017       2.33                    window screen
# 21           100019       1.33        1 x1 rail decorative wood
# 22           100019       2.67       4 xbi 8 beadboard paneling
# 23           100019       2.33               4 x8 wood paneling
# 24           100019       1.33                         mdf 4 x8
# 25           100019       2.33              wainscot chair rail
# 26           100019       2.33          wainscot plank paneling
# 27           100021       2.00                   lawn sprinkler
# 28           100021       2.33               rainbird sprinkler
# 29           100022       2.67                  platform washer
# ...             ...        ...                              ...
# 240730       224399        NaN          bifold oak 6 panel door
# 240731       224400        NaN     200 amp. breaker double pole
# 240732       224401        NaN                 axle locking nut
# 240733       224402        NaN                           sheath
# 240734       224403        NaN              outdoor patio shade
# 240735       224404        NaN                      safety sign
# 240736       224405        NaN                      phone cable
# 240737       224406        NaN                         vanguard
# 240738       224407        NaN                     dummy handle
# 240739       224408        NaN         advanced drainage system
# 240740       224409        NaN                           led tv
# 240741       224410        NaN                        l molding
# 240742       224411        NaN                minwax polycrylic
# 240743       224412        NaN                         camellia
# 240744       224413        NaN                  black gas range
# 240745       224414        NaN                 submersible wire
# 240746       224415        NaN   32 kw generac protector series
# 240747       224416        NaN                     bathroom tap
# 240748       224417        NaN        ceiling fan light fixture
# 240749       224418        NaN                            peony
# 240750       224419        NaN                         paracord
# 240751       224420        NaN                2 in. 1 4-20 bolt
# 240752       224421        NaN                       bath chair
# 240753       224422        NaN                        1 2 brass
# 240754       224423        NaN                pivot shower door
# 240755       224424        NaN         24 white storage cabinet
# 240756       224425        NaN               adirondack cushion
# 240757       224426        NaN                               hb
# 240758       224427        NaN                       hex socket
# 240759       224428        NaN                   4 in. hole saw
#
#                                       product_description  \
# 0       angle make joint stronger , also provide consi...
# 1       angle make joint stronger , also provide consi...
# 2       behr premium textured deckover innovative soli...
# 3       update bathroom delta vero single handle showe...
# 4       update bathroom delta vero single handle showe...
# 5       achieving delicious result almost effortless w...
# 6       achieving delicious result almost effortless w...
# 7       achieving delicious result almost effortless w...
# 8       quantum adjustable 2 light led black emergency...
# 9       get house fara 3 4 in. xbi 3 in. xbi 8 ft. mdf...
# 10      valley view industry metal stake ( 4 pack ) 9 ...
# 11      recycler 22 in. personal pace variable speed s...
# 12      recycler 22 in. personal pace variable speed s...
# 13      recycler 22 in. personal pace variable speed s...
# 14      96 in. wide caramel simple weave rollup bamboo...
# 15      insinkerator sinktop switch single outlet insi...
# 16      make grilling great handsome functional grill ...
# 17      md building product 36 in. xbi 36 in. xbi 1 50...
# 18      md building product 36 in. xbi 36 in. xbi 1 50...
# 19      md building product 36 in. xbi 36 in. xbi 1 50...
# 20      md building product 36 in. xbi 36 in. xbi 1 50...
# 21      house fara 8 linear ft. primed mdf overlapping...
# 22      house fara 8 linear ft. primed mdf overlapping...
# 23      house fara 8 linear ft. primed mdf overlapping...
# 24      house fara 8 linear ft. primed mdf overlapping...
# 25      house fara 8 linear ft. primed mdf overlapping...
# 26      house fara 8 linear ft. primed mdf overlapping...
# 27      installed park backyard across globe , rain bi...
# 28      installed park backyard across globe , rain bi...
# 29      samsung 4.2 cu.ft. front load washer steam whi...
# ...                                                   ...
# 240730  give home custom look plantation styled bi fol...
# 240731  eaton csr 200 amp. double pole main breaker ki...
# 240732  push nut screw thread inward facing flange. fl...
# 240733  dicky utility knife sheath constructed rugged ...
# 240734  carefree resin durability , adding elegance ou...
# 240735  speakman branded emergency eyewash safety sign...
# 240736  pl-65111-01 plantronics phone accessory item. ...
# 240737  1940 in. back hint today. available flemish go...
# 240738  step designer style superior security kwikset ...
# 240739  1 2 in. xbi 100 ft. ip 125 psi nsf poly pipe e...
# 240740  enjoy optimal viewing area magnavox 50 in. 108...
# 240741  beautiful crown moulding great way separate de...
# 240742  minwax polycrylic protective finish protective...
# 240743  pink stella camellia southern living plant col...
# 240744  ge 30 in. 5.0 cu.ft. gas range self cleaning o...
# 240745  southwires submersible pump cable used submers...
# 240746  generacs new protector series diesel generator...
# 240747  clearflo brass toe tap bath drain work perfect...
# 240748  light kit xbi casablanca great design sure com...
# 240749  glidden premium 5 gal. satin latex exterior pa...
# 240750  paracord ideal camping , hiking outdoor activi...
# 240751  crown bolt 's shoulder bolt also known strippe...
# 240752  wheel chair accessible 's provide safe indepen...
# 240753  wood screw thread forming screw larger thread ...
# 240754  legend series framed swing stand alone continu...
# 240755  create neat yet stylish storage space organizi...
# 240756  bullnose adirondack chair cushion fit adironda...
# 240757  joist hanger designed provide support undernea...
# 240758  socket cap screw ideal application require wel...
# 240759  bosch quick change bi metal hole saw feature p...
#
#                          product_colour                             brand  \
# 0                                   NaN                simpson strong-tie
# 1                                   NaN                simpson strong-tie
# 2                     brown tugboat tan    behr premium textured deckover
# 3                                chrome                             delta
# 4                                chrome                             delta
# 5                       stainless steel                         whirlpool
# 6                       stainless steel                         whirlpool
# 7                       stainless steel                         whirlpool
# 8                                 black                 lithonia lighting
# 9                                 white                        house fara
# 10                 metallic silver gray              valley view industry
# 11                                  NaN                              toro
# 12                                  NaN                              toro
# 13                                  NaN                              toro
# 14      caramel fruitwood brown tan tan                       hampton bay
# 15                                black                      insinkerator
# 16                                black                            sunjoy
# 17                                  NaN               md building product
# 18                                  NaN               md building product
# 19                                  NaN               md building product
# 20                                  NaN               md building product
# 21                                white                        house fara
# 22                                white                        house fara
# 23                                white                        house fara
# 24                                white                        house fara
# 25                                white                        house fara
# 26                                white                        house fara
# 27                                black                         rain bird
# 28                                black                         rain bird
# 29                                white                           samsung
# ...                                 ...                               ...
# 240730                       golden oak           home fashion technology
# 240731                              NaN                             eaton
# 240732                              NaN                        crown bolt
# 240733                    gray tan gray                             dicky
# 240734                     beige bisque              patio living concept
# 240735                      green white                          speakman
# 240736                            black                       plantronics
# 240737      black textured beige bisque                            glomar
# 240738                              NaN                           kwikset
# 240739                              NaN          advanced drainage system
# 240740                              NaN                          magnavox
# 240741                            white                    ekena millwork
# 240742                              NaN                            minwax
# 240743                             pink  southern living plant collection
# 240744                            black                                ge
# 240745                            black                         southwire
# 240746                             gray                           generac
# 240747           brushed nickel vibrant                            kohler
# 240748                    maiden bronze                        casablanca
# 240749                              NaN                               NaN
# 240750                            black                          everbilt
# 240751                         metallic                        crown bolt
# 240752                            white                     universal tub
# 240753                              NaN                          everbilt
# 240754                              NaN               coastal shower door
# 240755                            white                        stufurhome
# 240756            alessandro spiceberry         home decorator collection
# 240757                              NaN                               NaN
# 240758                              NaN                               NaN
# 240759                             blue                             bosch
#
#        product_weight product_depth      ...       size_sequence_match_score  \
# 0                0.26           1.5      ...                        0.080000
# 1                0.26           1.5      ...                        0.095238
# 2                 NaN           NaN      ...                             NaN
# 3                 NaN         15.28      ...                             NaN
# 4                 NaN         15.28      ...                             NaN
# 5                67.1          18.5      ...                        0.057143
# 6                67.1          18.5      ...                        0.055556
# 7                67.1          18.5      ...                        0.000000
# 8                 1.5          2.75      ...                        0.058824
# 9                 NaN          0.75      ...                             NaN
# 10                NaN             1      ...                             NaN
# 11                 80           NaN      ...                             NaN
# 12                 80           NaN      ...                             NaN
# 13                 80           NaN      ...                             NaN
# 14               9.15             1      ...                        0.139535
# 15                NaN             4      ...                             NaN
# 16             101.43           NaN      ...                             NaN
# 17         1.188 lb .          0.02      ...                        0.060606
# 18         1.188 lb .          0.02      ...                        0.177778
# 19         1.188 lb .          0.02      ...                        0.054054
# 20         1.188 lb .          0.02      ...                        0.055556
# 21                NaN         0.312      ...                             NaN
# 22                NaN         0.312      ...                             NaN
# 23                NaN         0.312      ...                             NaN
# 24                NaN         0.312      ...                             NaN
# 25                NaN         0.312      ...                             NaN
# 26                NaN         0.312      ...                             NaN
# 27                NaN           NaN      ...                             NaN
# 28                NaN           NaN      ...                             NaN
# 29              193.8            33      ...                        0.064516
# ...               ...           ...      ...                             ...
# 240730          22.16           NaN      ...                             NaN
# 240731           2.55         3.215      ...                        0.200000
# 240732         0.0393           NaN      ...                             NaN
# 240733            NaN           1.6      ...                             NaN
# 240734             17          20 .      ...                        0.111111
# 240735            NaN          12.5      ...                             NaN
# 240736            NaN             4      ...                             NaN
# 240737             34            34      ...                        0.000000
# 240738              1           NaN      ...                             NaN
# 240739             32             5      ...                        0.117647
# 240740            NaN           NaN      ...                             NaN
# 240741            NaN          0.75      ...                             NaN
# 240742            NaN           NaN      ...                             NaN
# 240743            NaN           NaN      ...                             NaN
# 240744            190         28.75      ...                        0.121212
# 240745            NaN        13.625      ...                             NaN
# 240746           1455            81      ...                        0.046512
# 240747            NaN          8.25      ...                             NaN
# 240748       4.6 lb .          13.6      ...                        0.127660
# 240749            NaN           NaN      ...                             NaN
# 240750      0.2866006     1.4960638      ...                        0.000000
# 240751             .1           NaN      ...                             NaN
# 240752            254           NaN      ...                             NaN
# 240753         0.0287           NaN      ...                             NaN
# 240754             65           NaN      ...                             NaN
# 240755            NaN           NaN      ...                             NaN
# 240756            NaN           NaN      ...                             NaN
# 240757            NaN           NaN      ...                             NaN
# 240758            NaN           NaN      ...                             NaN
# 240759            NaN           NaN      ...                             NaN
#
#        size_levenshtein_ratio size_Jaccard_dist_norm ratio_size  \
# 0                    0.080000                    0.0        0.0
# 1                    0.095238                    0.0        0.0
# 2                         NaN                    NaN        NaN
# 3                         NaN                    NaN        NaN
# 4                         NaN                    NaN        NaN
# 5                    0.057143                    0.0        0.0
# 6                    0.055556                    0.0        0.0
# 7                    0.000000                    0.0        0.0
# 8                    0.058824                    0.0        0.0
# 9                         NaN                    NaN        NaN
# 10                        NaN                    NaN        NaN
# 11                        NaN                    NaN        NaN
# 12                        NaN                    NaN        NaN
# 13                        NaN                    NaN        NaN
# 14                   0.139535                    0.0        0.0
# 15                        NaN                    NaN        NaN
# 16                        NaN                    NaN        NaN
# 17                   0.060606                    0.0        0.0
# 18                   0.177778                    0.0        0.0
# 19                   0.054054                    0.0        0.0
# 20                   0.055556                    0.0        0.0
# 21                        NaN                    NaN        NaN
# 22                        NaN                    NaN        NaN
# 23                        NaN                    NaN        NaN
# 24                        NaN                    NaN        NaN
# 25                        NaN                    NaN        NaN
# 26                        NaN                    NaN        NaN
# 27                        NaN                    NaN        NaN
# 28                        NaN                    NaN        NaN
# 29                   0.064516                    0.0        0.0
# ...                       ...                    ...        ...
# 240730                    NaN                    NaN        NaN
# 240731               0.200000                    0.0        0.0
# 240732                    NaN                    NaN        NaN
# 240733                    NaN                    NaN        NaN
# 240734               0.111111                    0.0        0.0
# 240735                    NaN                    NaN        NaN
# 240736                    NaN                    NaN        NaN
# 240737               0.000000                    0.0        0.0
# 240738                    NaN                    NaN        NaN
# 240739               0.117647                    0.0        0.0
# 240740                    NaN                    NaN        NaN
# 240741                    NaN                    NaN        NaN
# 240742                    NaN                    NaN        NaN
# 240743                    NaN                    NaN        NaN
# 240744               0.121212                    0.0        0.0
# 240745                    NaN                    NaN        NaN
# 240746               0.139535                    0.0        0.0
# 240747                    NaN                    NaN        NaN
# 240748               0.170213                    0.0        0.0
# 240749                    NaN                    NaN        NaN
# 240750               0.000000                    0.0        0.0
# 240751                    NaN                    NaN        NaN
# 240752                    NaN                    NaN        NaN
# 240753                    NaN                    NaN        NaN
# 240754                    NaN                    NaN        NaN
# 240755                    NaN                    NaN        NaN
# 240756                    NaN                    NaN        NaN
# 240757                    NaN                    NaN        NaN
# 240758                    NaN                    NaN        NaN
# 240759                    NaN                    NaN        NaN
#
#        query_in_bullets common_words_query_and_bullets  \
# 0                   0.0                            1.0
# 1                   0.0                            1.0
# 2                   2.0                            1.0
# 3                   NaN                            NaN
# 4                   NaN                            NaN
# 5                   0.0                            0.0
# 6                   0.0                            0.0
# 7                   0.0                            0.0
# 8                   0.0                            1.0
# 9                   0.0                            1.0
# 10                  0.0                            2.0
# 11                  0.0                            3.0
# 12                  0.0                            0.0
# 13                  0.0                            0.0
# 14                  0.0                            0.0
# 15                  1.0                            1.0
# 16                  0.0                            1.0
# 17                  0.0                            1.0
# 18                  0.0                            0.0
# 19                  0.0                            0.0
# 20                  1.0                            2.0
# 21                  0.0                            2.0
# 22                  0.0                            1.0
# 23                  0.0                            0.0
# 24                  0.0                            1.0
# 25                  0.0                            3.0
# 26                  0.0                            1.0
# 27                  0.0                            1.0
# 28                  0.0                            1.0
# 29                  0.0                            0.0
# ...                 ...                            ...
# 240730              0.0                            1.0
# 240731              0.0                            1.0
# 240732              0.0                            0.0
# 240733              NaN                            NaN
# 240734              0.0                            1.0
# 240735              NaN                            NaN
# 240736              NaN                            NaN
# 240737              0.0                            0.0
# 240738              0.0                            0.0
# 240739              NaN                            NaN
# 240740              0.0                            0.0
# 240741              0.0                            1.0
# 240742              NaN                            NaN
# 240743              0.0                            0.0
# 240744              0.0                            2.0
# 240745              0.0                            0.0
# 240746              0.0                            2.0
# 240747              0.0                            1.0
# 240748              0.0                            3.0
# 240749              NaN                            NaN
# 240750              4.0                            1.0
# 240751              NaN                            NaN
# 240752              0.0                            1.0
# 240753              0.0                            3.0
# 240754              0.0                            2.0
# 240755              0.0                            0.0
# 240756              0.0                            0.0
# 240757              NaN                            NaN
# 240758              NaN                            NaN
# 240759              NaN                            NaN
#
#        bullets_sequence_match_score  bullets_levenshtein_ratio  \
# 0                          0.008658                   0.095238
# 1                          0.008811                   0.061674
# 2                          0.000000                   0.029304
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# 5                          0.008163                   0.057143
# 6                          0.024440                   0.061100
# 7                          0.016495                   0.037113
# 8                          0.000000                   0.090278
# 9                          0.114943                   0.114943
# 10                         0.110497                   0.110497
# 11                         0.010554                   0.131926
# 12                         0.011050                   0.049724
# 13                         0.010989                   0.060440
# 14                         0.200000                   0.200000
# 15                         0.005952                   0.047619
# 16                         0.139241                   0.139241
# 17                         0.102273                   0.102273
# 18                         0.138298                   0.159574
# 19                         0.122222                   0.155556
# 20                         0.145251                   0.145251
# 21                         0.051282                   0.170940
# 22                         0.051064                   0.178723
# 23                         0.052863                   0.132159
# 24                         0.046083                   0.055300
# 25                         0.166667                   0.166667
# 26                         0.120690                   0.181034
# 27                         0.067568                   0.094595
# 28                         0.073333                   0.113333
# 29                         0.006993                   0.052448
# ...                             ...                        ...
# 240730                     0.111111                   0.181818
# 240731                     0.181818                   0.210526
# 240732                     0.175824                   0.219780
# 240733                          NaN                        NaN
# 240734                     0.250000                   0.285714
# 240735                          NaN                        NaN
# 240736                          NaN                        NaN
# 240737                     0.088889                   0.133333
# 240738                     0.023256                   0.077519
# 240739                          NaN                        NaN
# 240740                     0.008734                   0.052402
# 240741                     0.081633                   0.081633
# 240742                          NaN                        NaN
# 240743                     0.018692                   0.074766
# 240744                     0.011561                   0.080925
# 240745                     0.160494                   0.160494
# 240746                     0.005714                   0.082857
# 240747                     0.012012                   0.072072
# 240748                     0.262500                   0.287500
# 240749                          NaN                        NaN
# 240750                     0.000000                   0.031373
# 240751                          NaN                        NaN
# 240752                     0.000000                   0.048544
# 240753                     0.142857                   0.142857
# 240754                     0.012422                   0.099379
# 240755                     0.198675                   0.225166
# 240756                     0.128655                   0.128655
# 240757                          NaN                        NaN
# 240758                          NaN                        NaN
# 240759                          NaN                        NaN
#
#         bullets_Jaccard_dist_norm  ratio_bullets
# 0                        0.000000       0.500000
# 1                        0.000000       0.500000
# 2                        0.024390       1.000000
# 3                             NaN            NaN
# 4                             NaN            NaN
# 5                        0.000000       0.000000
# 6                        0.000000       0.000000
# 7                        0.000000       0.000000
# 8                        0.033333       0.500000
# 9                        0.000000       0.333333
# 10                       0.083333       1.000000
# 11                       0.038462       0.750000
# 12                       0.000000       0.000000
# 13                       0.000000       0.000000
# 14                       0.000000       0.000000
# 15                       0.000000       1.000000
# 16                       0.045455       0.500000
# 17                       0.037037       0.500000
# 18                       0.000000       0.000000
# 19                       0.000000       0.000000
# 20                       0.076923       1.000000
# 21                       0.033333       0.400000
# 22                       0.033333       0.200000
# 23                       0.000000       0.000000
# 24                       0.035714       0.333333
# 25                       0.115385       1.000000
# 26                       0.035714       0.333333
# 27                       0.027027       0.500000
# 28                       0.027027       0.500000
# 29                       0.000000       0.000000
# ...                           ...            ...
# 240730                   0.038462       0.200000
# 240731                   0.045455       0.200000
# 240732                   0.000000       0.000000
# 240733                        NaN            NaN
# 240734                   0.071429       0.333333
# 240735                        NaN            NaN
# 240736                        NaN            NaN
# 240737                   0.000000       0.000000
# 240738                   0.000000       0.000000
# 240739                        NaN            NaN
# 240740                   0.000000       0.000000
# 240741                   0.000000       0.500000
# 240742                        NaN            NaN
# 240743                   0.000000       0.000000
# 240744                   0.043478       0.666667
# 240745                   0.000000       0.000000
# 240746                   0.026667       0.400000
# 240747                   0.000000       0.500000
# 240748                   0.166667       0.750000
# 240749                        NaN            NaN
# 240750                   0.018182       1.000000
# 240751                        NaN            NaN
# 240752                   0.000000       0.500000
# 240753                   0.117647       1.000000
# 240754                   0.054054       0.666667
# 240755                   0.000000       0.000000
# 240756                   0.000000       0.000000
# 240757                        NaN            NaN
# 240758                        NaN            NaN
# 240759                        NaN            NaN
#
# [240760 rows x 64 columns]

# %%
df_all.to_csv('ready.csv')
